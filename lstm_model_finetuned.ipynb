# %%
import pandas as pd
import re
from transformers import pipeline

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount("/content/drive")
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
# %cd "/content"
# Out:
# /content

# %%
tesla_tweets = pd.read_csv('tesla_and_others.csv')
print(tesla_tweets.head())
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
tesla_tweets = tesla_tweets[tesla_tweets['Stock Name'] == 'TSLA']
print(tesla_tweets.head())
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
tesla_tweets['Tweet'] = tesla_tweets['Tweet'].apply(lambda x: re.sub(r'http\S+|www.\S+|@\w+|#\w+', '', x))
tesla_tweets['Tweet'] = tesla_tweets['Tweet'].str.lower()
tesla_tweets['Date'] = pd.to_datetime(tesla_tweets['Date']).dt.date
print(tesla_tweets['Date'].head())
# Out:
# 0    2022-09-29
# 1    2022-09-29
# 2    2022-09-29
# 3    2022-09-29
# 4    2022-09-29
# Name: Date, dtype: object

# %%
tesla_tweets = tesla_tweets.dropna(subset=['Tweet', 'Date']).drop_duplicates()
tesla_tweets = tesla_tweets.drop_duplicates(subset='Tweet')
tesla_tweets = tesla_tweets.drop(columns=['Stock Name', 'Company Name'], errors='ignore')
print(tesla_tweets.head())
# Out:
#          Date                                              Tweet
# 0  2022-09-29  mainstream media has done an amazing job at br...
# 1  2022-09-29  tesla delivery estimates are at around 364k fr...
# 2  2022-09-29  3/ even if i include 63.0m unvested rsus as of...
# 3  2022-09-29     hahaha why are you still trying to stop tes...
# 4  2022-09-29    stop trying to kill kids, you sad deranged o...

# %%
num_rows = tesla_tweets.shape[0]
start_date = tesla_tweets['Date'].min()
end_date = tesla_tweets['Date'].max()

print(f'Number of rows in the cleaned data: {num_rows}')
print(f'Start date of tweets: {start_date}')
print(f'End date of tweets: {end_date}')
# Out:
# Number of rows in the cleaned data: 37106
# Start date of tweets: 2021-09-30
# End date of tweets: 2022-09-29

# %%
# %cd "/content/drive/MyDrive/cs7643"
# Out:
# /content/drive/MyDrive/cs7643

# %%
# load FinBERT model for sentiment analysis
# sentiment_pipeline = pipeline('sentiment-analysis', model='yiyanghkust/finbert-tone', tokenizer='yiyanghkust/finbert-tone', device=0)
sentiment_pipeline = pipeline('sentiment-analysis', model='./finetuned_model', tokenizer='./finetuned_model', device=0)

# run sentiment classification on the 'Tweet' column in batches with truncation
sentiment_pipeline.tokenizer.model_max_length = 512
sentiment_pipeline.tokenizer.truncation = True
batch_size = 16
tweet_texts = tesla_tweets['Tweet'].tolist()

sentiment_results = []
for i in range(0, len(tweet_texts), batch_size):
    print(f'Start: i={i}')
    batch = tweet_texts[i:i + batch_size]
    sentiments = sentiment_pipeline(batch, truncation = True)
    sentiment_results.extend(sentiments)
    print(f'End: i={i}')

tesla_tweets['Sentiment'] = [result['label'] for result in sentiment_results]
# Out:
# Start: i=0
# End: i=0
# Start: i=16
# End: i=16
# Start: i=32
# End: i=32
# Start: i=48
# End: i=48
# Start: i=64
# End: i=64
# Start: i=80
# End: i=80
# Start: i=96
# End: i=96
# Start: i=112
# End: i=112
# Start: i=128
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# End: i=128
# Start: i=144
# End: i=144
# Start: i=160
# End: i=160
# Start: i=176
# End: i=176
# Start: i=192
# End: i=192
# Start: i=208
# End: i=208
# Start: i=224
# End: i=224
# Start: i=240
# End: i=240
# Start: i=256
# End: i=256
# Start: i=272
# End: i=272
# Start: i=288
# End: i=288
# Start: i=304
# End: i=304
# Start: i=320
# End: i=320
# Start: i=336
# End: i=336
# Start: i=352
# End: i=352
# Start: i=368
# End: i=368
# Start: i=384
# End: i=384
# Start: i=400
# End: i=400
# Start: i=416
# End: i=416
# Start: i=432
# End: i=432
# Start: i=448
# End: i=448
# Start: i=464
# End: i=464
# Start: i=480
# End: i=480
# Start: i=496
# End: i=496
# Start: i=512
# End: i=512
# Start: i=528
# End: i=528
# Start: i=544
# End: i=544
# Start: i=560
# End: i=560
# Start: i=576
# End: i=576
# Start: i=592
# End: i=592
# Start: i=608
# End: i=608
# Start: i=624
# End: i=624
# Start: i=640
# End: i=640
# Start: i=656
# End: i=656
# Start: i=672
# End: i=672
# Start: i=688
# End: i=688
# Start: i=704
# End: i=704
# Start: i=720
# End: i=720
# Start: i=736
# End: i=736
# Start: i=752
# End: i=752
# Start: i=768
# End: i=768
# Start: i=784
# End: i=784
# Start: i=800
# End: i=800
# Start: i=816
# End: i=816
# Start: i=832
# End: i=832
# Start: i=848
# End: i=848
# Start: i=864
# End: i=864
# Start: i=880
# End: i=880
# Start: i=896
# End: i=896
# Start: i=912
# End: i=912
# Start: i=928
# End: i=928
# Start: i=944
# End: i=944
# Start: i=960
# End: i=960
# Start: i=976
# End: i=976
# Start: i=992
# End: i=992
# Start: i=1008
# End: i=1008
# Start: i=1024
# End: i=1024
# Start: i=1040
# End: i=1040
# Start: i=1056
# End: i=1056
# Start: i=1072
# End: i=1072
# Start: i=1088
# End: i=1088
# Start: i=1104
# End: i=1104
# Start: i=1120
# End: i=1120
# Start: i=1136
# End: i=1136
# Start: i=1152
# End: i=1152
# Start: i=1168
# End: i=1168
# Start: i=1184
# End: i=1184
# Start: i=1200
# End: i=1200
# Start: i=1216
# End: i=1216
# Start: i=1232
# End: i=1232
# Start: i=1248
# End: i=1248
# Start: i=1264
# End: i=1264
# Start: i=1280
# End: i=1280
# Start: i=1296
# End: i=1296
# Start: i=1312
# End: i=1312
# Start: i=1328
# End: i=1328
# Start: i=1344
# End: i=1344
# Start: i=1360
# End: i=1360
# Start: i=1376
# End: i=1376
# Start: i=1392
# End: i=1392
# Start: i=1408
# End: i=1408
# Start: i=1424
# End: i=1424
# Start: i=1440
# End: i=1440
# Start: i=1456
# End: i=1456
# Start: i=1472
# End: i=1472
# Start: i=1488
# End: i=1488
# Start: i=1504
# End: i=1504
# Start: i=1520
# End: i=1520
# Start: i=1536
# End: i=1536
# Start: i=1552
# End: i=1552
# Start: i=1568
# End: i=1568
# Start: i=1584
# End: i=1584
# Start: i=1600
# End: i=1600
# Start: i=1616
# End: i=1616
# Start: i=1632
# End: i=1632
# Start: i=1648
# End: i=1648
# Start: i=1664
# End: i=1664
# Start: i=1680
# End: i=1680
# Start: i=1696
# End: i=1696
# Start: i=1712
# End: i=1712
# Start: i=1728
# End: i=1728
# Start: i=1744
# End: i=1744
# Start: i=1760
# End: i=1760
# Start: i=1776
# End: i=1776
# Start: i=1792
# End: i=1792
# Start: i=1808
# End: i=1808
# Start: i=1824
# End: i=1824
# Start: i=1840
# End: i=1840
# Start: i=1856
# End: i=1856
# Start: i=1872
# End: i=1872
# Start: i=1888
# End: i=1888
# Start: i=1904
# End: i=1904
# Start: i=1920
# End: i=1920
# Start: i=1936
# End: i=1936
# Start: i=1952
# End: i=1952
# Start: i=1968
# End: i=1968
# Start: i=1984
# End: i=1984
# Start: i=2000
# End: i=2000
# Start: i=2016
# End: i=2016
# Start: i=2032
# End: i=2032
# Start: i=2048
# End: i=2048
# Start: i=2064
# End: i=2064
# Start: i=2080
# End: i=2080
# Start: i=2096
# End: i=2096
# Start: i=2112
# End: i=2112
# Start: i=2128
# End: i=2128
# Start: i=2144
# End: i=2144
# Start: i=2160
# End: i=2160
# Start: i=2176
# End: i=2176
# Start: i=2192
# End: i=2192
# Start: i=2208
# End: i=2208
# Start: i=2224
# End: i=2224
# Start: i=2240
# End: i=2240
# Start: i=2256
# End: i=2256
# Start: i=2272
# End: i=2272
# Start: i=2288
# End: i=2288
# Start: i=2304
# End: i=2304
# Start: i=2320
# End: i=2320
# Start: i=2336
# End: i=2336
# Start: i=2352
# End: i=2352
# Start: i=2368
# End: i=2368
# Start: i=2384
# End: i=2384
# Start: i=2400
# End: i=2400
# Start: i=2416
# End: i=2416
# Start: i=2432
# End: i=2432
# Start: i=2448
# End: i=2448
# Start: i=2464
# End: i=2464
# Start: i=2480
# End: i=2480
# Start: i=2496
# End: i=2496
# Start: i=2512
# End: i=2512
# Start: i=2528
# End: i=2528
# Start: i=2544
# End: i=2544
# Start: i=2560
# End: i=2560
# Start: i=2576
# End: i=2576
# Start: i=2592
# End: i=2592
# Start: i=2608
# End: i=2608
# Start: i=2624
# End: i=2624
# Start: i=2640
# End: i=2640
# Start: i=2656
# End: i=2656
# Start: i=2672
# End: i=2672
# Start: i=2688
# End: i=2688
# Start: i=2704
# End: i=2704
# Start: i=2720
# End: i=2720
# Start: i=2736
# End: i=2736
# Start: i=2752
# End: i=2752
# Start: i=2768
# End: i=2768
# Start: i=2784
# End: i=2784
# Start: i=2800
# End: i=2800
# Start: i=2816
# End: i=2816
# Start: i=2832
# End: i=2832
# Start: i=2848
# End: i=2848
# Start: i=2864
# End: i=2864
# Start: i=2880
# End: i=2880
# Start: i=2896
# End: i=2896
# Start: i=2912
# End: i=2912
# Start: i=2928
# End: i=2928
# Start: i=2944
# End: i=2944
# Start: i=2960
# End: i=2960
# Start: i=2976
# End: i=2976
# Start: i=2992
# End: i=2992
# Start: i=3008
# End: i=3008
# Start: i=3024
# End: i=3024
# Start: i=3040
# End: i=3040
# Start: i=3056
# End: i=3056
# Start: i=3072
# End: i=3072
# Start: i=3088
# End: i=3088
# Start: i=3104
# End: i=3104
# Start: i=3120
# End: i=3120
# Start: i=3136
# End: i=3136
# Start: i=3152
# End: i=3152
# Start: i=3168
# End: i=3168
# Start: i=3184
# End: i=3184
# Start: i=3200
# End: i=3200
# Start: i=3216
# End: i=3216
# Start: i=3232
# End: i=3232
# Start: i=3248
# End: i=3248
# Start: i=3264
# End: i=3264
# Start: i=3280
# End: i=3280
# Start: i=3296
# End: i=3296
# Start: i=3312
# End: i=3312
# Start: i=3328
# End: i=3328
# Start: i=3344
# End: i=3344
# Start: i=3360
# End: i=3360
# Start: i=3376
# End: i=3376
# Start: i=3392
# End: i=3392
# Start: i=3408
# End: i=3408
# Start: i=3424
# End: i=3424
# Start: i=3440
# End: i=3440
# Start: i=3456
# End: i=3456
# Start: i=3472
# End: i=3472
# Start: i=3488
# End: i=3488
# Start: i=3504
# End: i=3504
# Start: i=3520
# End: i=3520
# Start: i=3536
# End: i=3536
# Start: i=3552
# End: i=3552
# Start: i=3568
# End: i=3568
# Start: i=3584
# End: i=3584
# Start: i=3600
# End: i=3600
# Start: i=3616
# End: i=3616
# Start: i=3632
# End: i=3632
# Start: i=3648
# End: i=3648
# Start: i=3664
# End: i=3664
# Start: i=3680
# End: i=3680
# Start: i=3696
# End: i=3696
# Start: i=3712
# End: i=3712
# Start: i=3728
# End: i=3728
# Start: i=3744
# End: i=3744
# Start: i=3760
# End: i=3760
# Start: i=3776
# End: i=3776
# Start: i=3792
# End: i=3792
# Start: i=3808
# End: i=3808
# Start: i=3824
# End: i=3824
# Start: i=3840
# End: i=3840
# Start: i=3856
# End: i=3856
# Start: i=3872
# End: i=3872
# Start: i=3888
# End: i=3888
# Start: i=3904
# End: i=3904
# Start: i=3920
# End: i=3920
# Start: i=3936
# End: i=3936
# Start: i=3952
# End: i=3952
# Start: i=3968
# End: i=3968
# Start: i=3984
# End: i=3984
# Start: i=4000
# End: i=4000
# Start: i=4016
# End: i=4016
# Start: i=4032
# End: i=4032
# Start: i=4048
# End: i=4048
# Start: i=4064
# End: i=4064
# Start: i=4080
# End: i=4080
# Start: i=4096
# End: i=4096
# Start: i=4112
# End: i=4112
# Start: i=4128
# End: i=4128
# Start: i=4144
# End: i=4144
# Start: i=4160
# End: i=4160
# Start: i=4176
# End: i=4176
# Start: i=4192
# End: i=4192
# Start: i=4208
# End: i=4208
# Start: i=4224
# End: i=4224
# Start: i=4240
# End: i=4240
# Start: i=4256
# End: i=4256
# Start: i=4272
# End: i=4272
# Start: i=4288
# End: i=4288
# Start: i=4304
# End: i=4304
# Start: i=4320
# End: i=4320
# Start: i=4336
# End: i=4336
# Start: i=4352
# End: i=4352
# Start: i=4368
# End: i=4368
# Start: i=4384
# End: i=4384
# Start: i=4400
# End: i=4400
# Start: i=4416
# End: i=4416
# Start: i=4432
# End: i=4432
# Start: i=4448
# End: i=4448
# Start: i=4464
# End: i=4464
# Start: i=4480
# End: i=4480
# Start: i=4496
# End: i=4496
# Start: i=4512
# End: i=4512
# Start: i=4528
# End: i=4528
# Start: i=4544
# End: i=4544
# Start: i=4560
# End: i=4560
# Start: i=4576
# End: i=4576
# Start: i=4592
# End: i=4592
# Start: i=4608
# End: i=4608
# Start: i=4624
# End: i=4624
# Start: i=4640
# End: i=4640
# Start: i=4656
# End: i=4656
# Start: i=4672
# End: i=4672
# Start: i=4688
# End: i=4688
# Start: i=4704
# End: i=4704
# Start: i=4720
# End: i=4720
# Start: i=4736
# End: i=4736
# Start: i=4752
# End: i=4752
# Start: i=4768
# End: i=4768
# Start: i=4784
# End: i=4784
# Start: i=4800
# End: i=4800
# Start: i=4816
# End: i=4816
# Start: i=4832
# End: i=4832
# Start: i=4848
# End: i=4848
# Start: i=4864
# End: i=4864
# Start: i=4880
# End: i=4880
# Start: i=4896
# End: i=4896
# Start: i=4912
# End: i=4912
# Start: i=4928
# End: i=4928
# Start: i=4944
# End: i=4944
# Start: i=4960
# End: i=4960
# Start: i=4976
# End: i=4976
# Start: i=4992
# End: i=4992
# Start: i=5008
# End: i=5008
# Start: i=5024
# End: i=5024
# Start: i=5040
# End: i=5040
# Start: i=5056
# End: i=5056
# Start: i=5072
# End: i=5072
# Start: i=5088
# End: i=5088
# Start: i=5104
# End: i=5104
# Start: i=5120
# End: i=5120
# Start: i=5136
# End: i=5136
# Start: i=5152
# End: i=5152
# Start: i=5168
# End: i=5168
# Start: i=5184
# End: i=5184
# Start: i=5200
# End: i=5200
# Start: i=5216
# End: i=5216
# Start: i=5232
# End: i=5232
# Start: i=5248
# End: i=5248
# Start: i=5264
# End: i=5264
# Start: i=5280
# End: i=5280
# Start: i=5296
# End: i=5296
# Start: i=5312
# End: i=5312
# Start: i=5328
# End: i=5328
# Start: i=5344
# End: i=5344
# Start: i=5360
# End: i=5360
# Start: i=5376
# End: i=5376
# Start: i=5392
# End: i=5392
# Start: i=5408
# End: i=5408
# Start: i=5424
# End: i=5424
# Start: i=5440
# End: i=5440
# Start: i=5456
# End: i=5456
# Start: i=5472
# End: i=5472
# Start: i=5488
# End: i=5488
# Start: i=5504
# End: i=5504
# Start: i=5520
# End: i=5520
# Start: i=5536
# End: i=5536
# Start: i=5552
# End: i=5552
# Start: i=5568
# End: i=5568
# Start: i=5584
# End: i=5584
# Start: i=5600
# End: i=5600
# Start: i=5616
# End: i=5616
# Start: i=5632
# End: i=5632
# Start: i=5648
# End: i=5648
# Start: i=5664
# End: i=5664
# Start: i=5680
# End: i=5680
# Start: i=5696
# End: i=5696
# Start: i=5712
# End: i=5712
# Start: i=5728
# End: i=5728
# Start: i=5744
# End: i=5744
# Start: i=5760
# End: i=5760
# Start: i=5776
# End: i=5776
# Start: i=5792
# End: i=5792
# Start: i=5808
# End: i=5808
# Start: i=5824
# End: i=5824
# Start: i=5840
# End: i=5840
# Start: i=5856
# End: i=5856
# Start: i=5872
# End: i=5872
# Start: i=5888
# End: i=5888
# Start: i=5904
# End: i=5904
# Start: i=5920
# End: i=5920
# Start: i=5936
# End: i=5936
# Start: i=5952
# End: i=5952
# Start: i=5968
# End: i=5968
# Start: i=5984
# End: i=5984
# Start: i=6000
# End: i=6000
# Start: i=6016
# End: i=6016
# Start: i=6032
# End: i=6032
# Start: i=6048
# End: i=6048
# Start: i=6064
# End: i=6064
# Start: i=6080
# End: i=6080
# Start: i=6096
# End: i=6096
# Start: i=6112
# End: i=6112
# Start: i=6128
# End: i=6128
# Start: i=6144
# End: i=6144
# Start: i=6160
# End: i=6160
# Start: i=6176
# End: i=6176
# Start: i=6192
# End: i=6192
# Start: i=6208
# End: i=6208
# Start: i=6224
# End: i=6224
# Start: i=6240
# End: i=6240
# Start: i=6256
# End: i=6256
# Start: i=6272
# End: i=6272
# Start: i=6288
# End: i=6288
# Start: i=6304
# End: i=6304
# Start: i=6320
# End: i=6320
# Start: i=6336
# End: i=6336
# Start: i=6352
# End: i=6352
# Start: i=6368
# End: i=6368
# Start: i=6384
# End: i=6384
# Start: i=6400
# End: i=6400
# Start: i=6416
# End: i=6416
# Start: i=6432
# End: i=6432
# Start: i=6448
# End: i=6448
# Start: i=6464
# End: i=6464
# Start: i=6480
# End: i=6480
# Start: i=6496
# End: i=6496
# Start: i=6512
# End: i=6512
# Start: i=6528
# End: i=6528
# Start: i=6544
# End: i=6544
# Start: i=6560
# End: i=6560
# Start: i=6576
# End: i=6576
# Start: i=6592
# End: i=6592
# Start: i=6608
# End: i=6608
# Start: i=6624
# End: i=6624
# Start: i=6640
# End: i=6640
# Start: i=6656
# End: i=6656
# Start: i=6672
# End: i=6672
# Start: i=6688
# End: i=6688
# Start: i=6704
# End: i=6704
# Start: i=6720
# End: i=6720
# Start: i=6736
# End: i=6736
# Start: i=6752
# End: i=6752
# Start: i=6768
# End: i=6768
# Start: i=6784
# End: i=6784
# Start: i=6800
# End: i=6800
# Start: i=6816
# End: i=6816
# Start: i=6832
# End: i=6832
# Start: i=6848
# End: i=6848
# Start: i=6864
# End: i=6864
# Start: i=6880
# End: i=6880
# Start: i=6896
# End: i=6896
# Start: i=6912
# End: i=6912
# Start: i=6928
# End: i=6928
# Start: i=6944
# End: i=6944
# Start: i=6960
# End: i=6960
# Start: i=6976
# End: i=6976
# Start: i=6992
# End: i=6992
# Start: i=7008
# End: i=7008
# Start: i=7024
# End: i=7024
# Start: i=7040
# End: i=7040
# Start: i=7056
# End: i=7056
# Start: i=7072
# End: i=7072
# Start: i=7088
# End: i=7088
# Start: i=7104
# End: i=7104
# Start: i=7120
# End: i=7120
# Start: i=7136
# End: i=7136
# Start: i=7152
# End: i=7152
# Start: i=7168
# End: i=7168
# Start: i=7184
# End: i=7184
# Start: i=7200
# End: i=7200
# Start: i=7216
# End: i=7216
# Start: i=7232
# End: i=7232
# Start: i=7248
# End: i=7248
# Start: i=7264
# End: i=7264
# Start: i=7280
# End: i=7280
# Start: i=7296
# End: i=7296
# Start: i=7312
# End: i=7312
# Start: i=7328
# End: i=7328
# Start: i=7344
# End: i=7344
# Start: i=7360
# End: i=7360
# Start: i=7376
# End: i=7376
# Start: i=7392
# End: i=7392
# Start: i=7408
# End: i=7408
# Start: i=7424
# End: i=7424
# Start: i=7440
# End: i=7440
# Start: i=7456
# End: i=7456
# Start: i=7472
# End: i=7472
# Start: i=7488
# End: i=7488
# Start: i=7504
# End: i=7504
# Start: i=7520
# End: i=7520
# Start: i=7536
# End: i=7536
# Start: i=7552
# End: i=7552
# Start: i=7568
# End: i=7568
# Start: i=7584
# End: i=7584
# Start: i=7600
# End: i=7600
# Start: i=7616
# End: i=7616
# Start: i=7632
# End: i=7632
# Start: i=7648
# End: i=7648
# Start: i=7664
# End: i=7664
# Start: i=7680
# End: i=7680
# Start: i=7696
# End: i=7696
# Start: i=7712
# End: i=7712
# Start: i=7728
# End: i=7728
# Start: i=7744
# End: i=7744
# Start: i=7760
# End: i=7760
# Start: i=7776
# End: i=7776
# Start: i=7792
# End: i=7792
# Start: i=7808
# End: i=7808
# Start: i=7824
# End: i=7824
# Start: i=7840
# End: i=7840
# Start: i=7856
# End: i=7856
# Start: i=7872
# End: i=7872
# Start: i=7888
# End: i=7888
# Start: i=7904
# End: i=7904
# Start: i=7920
# End: i=7920
# Start: i=7936
# End: i=7936
# Start: i=7952
# End: i=7952
# Start: i=7968
# End: i=7968
# Start: i=7984
# End: i=7984
# Start: i=8000
# End: i=8000
# Start: i=8016
# End: i=8016
# Start: i=8032
# End: i=8032
# Start: i=8048
# End: i=8048
# Start: i=8064
# End: i=8064
# Start: i=8080
# End: i=8080
# Start: i=8096
# End: i=8096
# Start: i=8112
# End: i=8112
# Start: i=8128
# End: i=8128
# Start: i=8144
# End: i=8144
# Start: i=8160
# End: i=8160
# Start: i=8176
# End: i=8176
# Start: i=8192
# End: i=8192
# Start: i=8208
# End: i=8208
# Start: i=8224
# End: i=8224
# Start: i=8240
# End: i=8240
# Start: i=8256
# End: i=8256
# Start: i=8272
# End: i=8272
# Start: i=8288
# End: i=8288
# Start: i=8304
# End: i=8304
# Start: i=8320
# End: i=8320
# Start: i=8336
# End: i=8336
# Start: i=8352
# End: i=8352
# Start: i=8368
# End: i=8368
# Start: i=8384
# End: i=8384
# Start: i=8400
# End: i=8400
# Start: i=8416
# End: i=8416
# Start: i=8432
# End: i=8432
# Start: i=8448
# End: i=8448
# Start: i=8464
# End: i=8464
# Start: i=8480
# End: i=8480
# Start: i=8496
# End: i=8496
# Start: i=8512
# End: i=8512
# Start: i=8528
# End: i=8528
# Start: i=8544
# End: i=8544
# Start: i=8560
# End: i=8560
# Start: i=8576
# End: i=8576
# Start: i=8592
# End: i=8592
# Start: i=8608
# End: i=8608
# Start: i=8624
# End: i=8624
# Start: i=8640
# End: i=8640
# Start: i=8656
# End: i=8656
# Start: i=8672
# End: i=8672
# Start: i=8688
# End: i=8688
# Start: i=8704
# End: i=8704
# Start: i=8720
# End: i=8720
# Start: i=8736
# End: i=8736
# Start: i=8752
# End: i=8752
# Start: i=8768
# End: i=8768
# Start: i=8784
# End: i=8784
# Start: i=8800
# End: i=8800
# Start: i=8816
# End: i=8816
# Start: i=8832
# End: i=8832
# Start: i=8848
# End: i=8848
# Start: i=8864
# End: i=8864
# Start: i=8880
# End: i=8880
# Start: i=8896
# End: i=8896
# Start: i=8912
# End: i=8912
# Start: i=8928
# End: i=8928
# Start: i=8944
# End: i=8944
# Start: i=8960
# End: i=8960
# Start: i=8976
# End: i=8976
# Start: i=8992
# End: i=8992
# Start: i=9008
# End: i=9008
# Start: i=9024
# End: i=9024
# Start: i=9040
# End: i=9040
# Start: i=9056
# End: i=9056
# Start: i=9072
# End: i=9072
# Start: i=9088
# End: i=9088
# Start: i=9104
# End: i=9104
# Start: i=9120
# End: i=9120
# Start: i=9136
# End: i=9136
# Start: i=9152
# End: i=9152
# Start: i=9168
# End: i=9168
# Start: i=9184
# End: i=9184
# Start: i=9200
# End: i=9200
# Start: i=9216
# End: i=9216
# Start: i=9232
# End: i=9232
# Start: i=9248
# End: i=9248
# Start: i=9264
# End: i=9264
# Start: i=9280
# End: i=9280
# Start: i=9296
# End: i=9296
# Start: i=9312
# End: i=9312
# Start: i=9328
# End: i=9328
# Start: i=9344
# End: i=9344
# Start: i=9360
# End: i=9360
# Start: i=9376
# End: i=9376
# Start: i=9392
# End: i=9392
# Start: i=9408
# End: i=9408
# Start: i=9424
# End: i=9424
# Start: i=9440
# End: i=9440
# Start: i=9456
# End: i=9456
# Start: i=9472
# End: i=9472
# Start: i=9488
# End: i=9488
# Start: i=9504
# End: i=9504
# Start: i=9520
# End: i=9520
# Start: i=9536
# End: i=9536
# Start: i=9552
# End: i=9552
# Start: i=9568
# End: i=9568
# Start: i=9584
# End: i=9584
# Start: i=9600
# End: i=9600
# Start: i=9616
# End: i=9616
# Start: i=9632
# End: i=9632
# Start: i=9648
# End: i=9648
# Start: i=9664
# End: i=9664
# Start: i=9680
# End: i=9680
# Start: i=9696
# End: i=9696
# Start: i=9712
# End: i=9712
# Start: i=9728
# End: i=9728
# Start: i=9744
# End: i=9744
# Start: i=9760
# End: i=9760
# Start: i=9776
# End: i=9776
# Start: i=9792
# End: i=9792
# Start: i=9808
# End: i=9808
# Start: i=9824
# End: i=9824
# Start: i=9840
# End: i=9840
# Start: i=9856
# End: i=9856
# Start: i=9872
# End: i=9872
# Start: i=9888
# End: i=9888
# Start: i=9904
# End: i=9904
# Start: i=9920
# End: i=9920
# Start: i=9936
# End: i=9936
# Start: i=9952
# End: i=9952
# Start: i=9968
# End: i=9968
# Start: i=9984
# End: i=9984
# Start: i=10000
# End: i=10000
# Start: i=10016
# End: i=10016
# Start: i=10032
# End: i=10032
# Start: i=10048
# End: i=10048
# Start: i=10064
# End: i=10064
# Start: i=10080
# End: i=10080
# Start: i=10096
# End: i=10096
# Start: i=10112
# End: i=10112
# Start: i=10128
# End: i=10128
# Start: i=10144
# End: i=10144
# Start: i=10160
# End: i=10160
# Start: i=10176
# End: i=10176
# Start: i=10192
# End: i=10192
# Start: i=10208
# End: i=10208
# Start: i=10224
# End: i=10224
# Start: i=10240
# End: i=10240
# Start: i=10256
# End: i=10256
# Start: i=10272
# End: i=10272
# Start: i=10288
# End: i=10288
# Start: i=10304
# End: i=10304
# Start: i=10320
# End: i=10320
# Start: i=10336
# End: i=10336
# Start: i=10352
# End: i=10352
# Start: i=10368
# End: i=10368
# Start: i=10384
# End: i=10384
# Start: i=10400
# End: i=10400
# Start: i=10416
# End: i=10416
# Start: i=10432
# End: i=10432
# Start: i=10448
# End: i=10448
# Start: i=10464
# End: i=10464
# Start: i=10480
# End: i=10480
# Start: i=10496
# End: i=10496
# Start: i=10512
# End: i=10512
# Start: i=10528
# End: i=10528
# Start: i=10544
# End: i=10544
# Start: i=10560
# End: i=10560
# Start: i=10576
# End: i=10576
# Start: i=10592
# End: i=10592
# Start: i=10608
# End: i=10608
# Start: i=10624
# End: i=10624
# Start: i=10640
# End: i=10640
# Start: i=10656
# End: i=10656
# Start: i=10672
# End: i=10672
# Start: i=10688
# End: i=10688
# Start: i=10704
# End: i=10704
# Start: i=10720
# End: i=10720
# Start: i=10736
# End: i=10736
# Start: i=10752
# End: i=10752
# Start: i=10768
# End: i=10768
# Start: i=10784
# End: i=10784
# Start: i=10800
# End: i=10800
# Start: i=10816
# End: i=10816
# Start: i=10832
# End: i=10832
# Start: i=10848
# End: i=10848
# Start: i=10864
# End: i=10864
# Start: i=10880
# End: i=10880
# Start: i=10896
# End: i=10896
# Start: i=10912
# End: i=10912
# Start: i=10928
# End: i=10928
# Start: i=10944
# End: i=10944
# Start: i=10960
# End: i=10960
# Start: i=10976
# End: i=10976
# Start: i=10992
# End: i=10992
# Start: i=11008
# End: i=11008
# Start: i=11024
# End: i=11024
# Start: i=11040
# End: i=11040
# Start: i=11056
# End: i=11056
# Start: i=11072
# End: i=11072
# Start: i=11088
# End: i=11088
# Start: i=11104
# End: i=11104
# Start: i=11120
# End: i=11120
# Start: i=11136
# End: i=11136
# Start: i=11152
# End: i=11152
# Start: i=11168
# End: i=11168
# Start: i=11184
# End: i=11184
# Start: i=11200
# End: i=11200
# Start: i=11216
# End: i=11216
# Start: i=11232
# End: i=11232
# Start: i=11248
# End: i=11248
# Start: i=11264
# End: i=11264
# Start: i=11280
# End: i=11280
# Start: i=11296
# End: i=11296
# Start: i=11312
# End: i=11312
# Start: i=11328
# End: i=11328
# Start: i=11344
# End: i=11344
# Start: i=11360
# End: i=11360
# Start: i=11376
# End: i=11376
# Start: i=11392
# End: i=11392
# Start: i=11408
# End: i=11408
# Start: i=11424
# End: i=11424
# Start: i=11440
# End: i=11440
# Start: i=11456
# End: i=11456
# Start: i=11472
# End: i=11472
# Start: i=11488
# End: i=11488
# Start: i=11504
# End: i=11504
# Start: i=11520
# End: i=11520
# Start: i=11536
# End: i=11536
# Start: i=11552
# End: i=11552
# Start: i=11568
# End: i=11568
# Start: i=11584
# End: i=11584
# Start: i=11600
# End: i=11600
# Start: i=11616
# End: i=11616
# Start: i=11632
# End: i=11632
# Start: i=11648
# End: i=11648
# Start: i=11664
# End: i=11664
# Start: i=11680
# End: i=11680
# Start: i=11696
# End: i=11696
# Start: i=11712
# End: i=11712
# Start: i=11728
# End: i=11728
# Start: i=11744
# End: i=11744
# Start: i=11760
# End: i=11760
# Start: i=11776
# End: i=11776
# Start: i=11792
# End: i=11792
# Start: i=11808
# End: i=11808
# Start: i=11824
# End: i=11824
# Start: i=11840
# End: i=11840
# Start: i=11856
# End: i=11856
# Start: i=11872
# End: i=11872
# Start: i=11888
# End: i=11888
# Start: i=11904
# End: i=11904
# Start: i=11920
# End: i=11920
# Start: i=11936
# End: i=11936
# Start: i=11952
# End: i=11952
# Start: i=11968
# End: i=11968
# Start: i=11984
# End: i=11984
# Start: i=12000
# End: i=12000
# Start: i=12016
# End: i=12016
# Start: i=12032
# End: i=12032
# Start: i=12048
# End: i=12048
# Start: i=12064
# End: i=12064
# Start: i=12080
# End: i=12080
# Start: i=12096
# End: i=12096
# Start: i=12112
# End: i=12112
# Start: i=12128
# End: i=12128
# Start: i=12144
# End: i=12144
# Start: i=12160
# End: i=12160
# Start: i=12176
# End: i=12176
# Start: i=12192
# End: i=12192
# Start: i=12208
# End: i=12208
# Start: i=12224
# End: i=12224
# Start: i=12240
# End: i=12240
# Start: i=12256
# End: i=12256
# Start: i=12272
# End: i=12272
# Start: i=12288
# End: i=12288
# Start: i=12304
# End: i=12304
# Start: i=12320
# End: i=12320
# Start: i=12336
# End: i=12336
# Start: i=12352
# End: i=12352
# Start: i=12368
# End: i=12368
# Start: i=12384
# End: i=12384
# Start: i=12400
# End: i=12400
# Start: i=12416
# End: i=12416
# Start: i=12432
# End: i=12432
# Start: i=12448
# End: i=12448
# Start: i=12464
# End: i=12464
# Start: i=12480
# End: i=12480
# Start: i=12496
# End: i=12496
# Start: i=12512
# End: i=12512
# Start: i=12528
# End: i=12528
# Start: i=12544
# End: i=12544
# Start: i=12560
# End: i=12560
# Start: i=12576
# End: i=12576
# Start: i=12592
# End: i=12592
# Start: i=12608
# End: i=12608
# Start: i=12624
# End: i=12624
# Start: i=12640
# End: i=12640
# Start: i=12656
# End: i=12656
# Start: i=12672
# End: i=12672
# Start: i=12688
# End: i=12688
# Start: i=12704
# End: i=12704
# Start: i=12720
# End: i=12720
# Start: i=12736
# End: i=12736
# Start: i=12752
# End: i=12752
# Start: i=12768
# End: i=12768
# Start: i=12784
# End: i=12784
# Start: i=12800
# End: i=12800
# Start: i=12816
# End: i=12816
# Start: i=12832
# End: i=12832
# Start: i=12848
# End: i=12848
# Start: i=12864
# End: i=12864
# Start: i=12880
# End: i=12880
# Start: i=12896
# End: i=12896
# Start: i=12912
# End: i=12912
# Start: i=12928
# End: i=12928
# Start: i=12944
# End: i=12944
# Start: i=12960
# End: i=12960
# Start: i=12976
# End: i=12976
# Start: i=12992
# End: i=12992
# Start: i=13008
# End: i=13008
# Start: i=13024
# End: i=13024
# Start: i=13040
# End: i=13040
# Start: i=13056
# End: i=13056
# Start: i=13072
# End: i=13072
# Start: i=13088
# End: i=13088
# Start: i=13104
# End: i=13104
# Start: i=13120
# End: i=13120
# Start: i=13136
# End: i=13136
# Start: i=13152
# End: i=13152
# Start: i=13168
# End: i=13168
# Start: i=13184
# End: i=13184
# Start: i=13200
# End: i=13200
# Start: i=13216
# End: i=13216
# Start: i=13232
# End: i=13232
# Start: i=13248
# End: i=13248
# Start: i=13264
# End: i=13264
# Start: i=13280
# End: i=13280
# Start: i=13296
# End: i=13296
# Start: i=13312
# End: i=13312
# Start: i=13328
# End: i=13328
# Start: i=13344
# End: i=13344
# Start: i=13360
# End: i=13360
# Start: i=13376
# End: i=13376
# Start: i=13392
# End: i=13392
# Start: i=13408
# End: i=13408
# Start: i=13424
# End: i=13424
# Start: i=13440
# End: i=13440
# Start: i=13456
# End: i=13456
# Start: i=13472
# End: i=13472
# Start: i=13488
# End: i=13488
# Start: i=13504
# End: i=13504
# Start: i=13520
# End: i=13520
# Start: i=13536
# End: i=13536
# Start: i=13552
# End: i=13552
# Start: i=13568
# End: i=13568
# Start: i=13584
# End: i=13584
# Start: i=13600
# End: i=13600
# Start: i=13616
# End: i=13616
# Start: i=13632
# End: i=13632
# Start: i=13648
# End: i=13648
# Start: i=13664
# End: i=13664
# Start: i=13680
# End: i=13680
# Start: i=13696
# End: i=13696
# Start: i=13712
# End: i=13712
# Start: i=13728
# End: i=13728
# Start: i=13744
# End: i=13744
# Start: i=13760
# End: i=13760
# Start: i=13776
# End: i=13776
# Start: i=13792
# End: i=13792
# Start: i=13808
# End: i=13808
# Start: i=13824
# End: i=13824
# Start: i=13840
# End: i=13840
# Start: i=13856
# End: i=13856
# Start: i=13872
# End: i=13872
# Start: i=13888
# End: i=13888
# Start: i=13904
# End: i=13904
# Start: i=13920
# End: i=13920
# Start: i=13936
# End: i=13936
# Start: i=13952
# End: i=13952
# Start: i=13968
# End: i=13968
# Start: i=13984
# End: i=13984
# Start: i=14000
# End: i=14000
# Start: i=14016
# End: i=14016
# Start: i=14032
# End: i=14032
# Start: i=14048
# End: i=14048
# Start: i=14064
# End: i=14064
# Start: i=14080
# End: i=14080
# Start: i=14096
# End: i=14096
# Start: i=14112
# End: i=14112
# Start: i=14128
# End: i=14128
# Start: i=14144
# End: i=14144
# Start: i=14160
# End: i=14160
# Start: i=14176
# End: i=14176
# Start: i=14192
# End: i=14192
# Start: i=14208
# End: i=14208
# Start: i=14224
# End: i=14224
# Start: i=14240
# End: i=14240
# Start: i=14256
# End: i=14256
# Start: i=14272
# End: i=14272
# Start: i=14288
# End: i=14288
# Start: i=14304
# End: i=14304
# Start: i=14320
# End: i=14320
# Start: i=14336
# End: i=14336
# Start: i=14352
# End: i=14352
# Start: i=14368
# End: i=14368
# Start: i=14384
# End: i=14384
# Start: i=14400
# End: i=14400
# Start: i=14416
# End: i=14416
# Start: i=14432
# End: i=14432
# Start: i=14448
# End: i=14448
# Start: i=14464
# End: i=14464
# Start: i=14480
# End: i=14480
# Start: i=14496
# End: i=14496
# Start: i=14512
# End: i=14512
# Start: i=14528
# End: i=14528
# Start: i=14544
# End: i=14544
# Start: i=14560
# End: i=14560
# Start: i=14576
# End: i=14576
# Start: i=14592
# End: i=14592
# Start: i=14608
# End: i=14608
# Start: i=14624
# End: i=14624
# Start: i=14640
# End: i=14640
# Start: i=14656
# End: i=14656
# Start: i=14672
# End: i=14672
# Start: i=14688
# End: i=14688
# Start: i=14704
# End: i=14704
# Start: i=14720
# End: i=14720
# Start: i=14736
# End: i=14736
# Start: i=14752
# End: i=14752
# Start: i=14768
# End: i=14768
# Start: i=14784
# End: i=14784
# Start: i=14800
# End: i=14800
# Start: i=14816
# End: i=14816
# Start: i=14832
# End: i=14832
# Start: i=14848
# End: i=14848
# Start: i=14864
# End: i=14864
# Start: i=14880
# End: i=14880
# Start: i=14896
# End: i=14896
# Start: i=14912
# End: i=14912
# Start: i=14928
# End: i=14928
# Start: i=14944
# End: i=14944
# Start: i=14960
# End: i=14960
# Start: i=14976
# End: i=14976
# Start: i=14992
# End: i=14992
# Start: i=15008
# End: i=15008
# Start: i=15024
# End: i=15024
# Start: i=15040
# End: i=15040
# Start: i=15056
# End: i=15056
# Start: i=15072
# End: i=15072
# Start: i=15088
# End: i=15088
# Start: i=15104
# End: i=15104
# Start: i=15120
# End: i=15120
# Start: i=15136
# End: i=15136
# Start: i=15152
# End: i=15152
# Start: i=15168
# End: i=15168
# Start: i=15184
# End: i=15184
# Start: i=15200
# End: i=15200
# Start: i=15216
# End: i=15216
# Start: i=15232
# End: i=15232
# Start: i=15248
# End: i=15248
# Start: i=15264
# End: i=15264
# Start: i=15280
# End: i=15280
# Start: i=15296
# End: i=15296
# Start: i=15312
# End: i=15312
# Start: i=15328
# End: i=15328
# Start: i=15344
# End: i=15344
# Start: i=15360
# End: i=15360
# Start: i=15376
# End: i=15376
# Start: i=15392
# End: i=15392
# Start: i=15408
# End: i=15408
# Start: i=15424
# End: i=15424
# Start: i=15440
# End: i=15440
# Start: i=15456
# End: i=15456
# Start: i=15472
# End: i=15472
# Start: i=15488
# End: i=15488
# Start: i=15504
# End: i=15504
# Start: i=15520
# End: i=15520
# Start: i=15536
# End: i=15536
# Start: i=15552
# End: i=15552
# Start: i=15568
# End: i=15568
# Start: i=15584
# End: i=15584
# Start: i=15600
# End: i=15600
# Start: i=15616
# End: i=15616
# Start: i=15632
# End: i=15632
# Start: i=15648
# End: i=15648
# Start: i=15664
# End: i=15664
# Start: i=15680
# End: i=15680
# Start: i=15696
# End: i=15696
# Start: i=15712
# End: i=15712
# Start: i=15728
# End: i=15728
# Start: i=15744
# End: i=15744
# Start: i=15760
# End: i=15760
# Start: i=15776
# End: i=15776
# Start: i=15792
# End: i=15792
# Start: i=15808
# End: i=15808
# Start: i=15824
# End: i=15824
# Start: i=15840
# End: i=15840
# Start: i=15856
# End: i=15856
# Start: i=15872
# End: i=15872
# Start: i=15888
# End: i=15888
# Start: i=15904
# End: i=15904
# Start: i=15920
# End: i=15920
# Start: i=15936
# End: i=15936
# Start: i=15952
# End: i=15952
# Start: i=15968
# End: i=15968
# Start: i=15984
# End: i=15984
# Start: i=16000
# End: i=16000
# Start: i=16016
# End: i=16016
# Start: i=16032
# End: i=16032
# Start: i=16048
# End: i=16048
# Start: i=16064
# End: i=16064
# Start: i=16080
# End: i=16080
# Start: i=16096
# End: i=16096
# Start: i=16112
# End: i=16112
# Start: i=16128
# End: i=16128
# Start: i=16144
# End: i=16144
# Start: i=16160
# End: i=16160
# Start: i=16176
# End: i=16176
# Start: i=16192
# End: i=16192
# Start: i=16208
# End: i=16208
# Start: i=16224
# End: i=16224
# Start: i=16240
# End: i=16240
# Start: i=16256
# End: i=16256
# Start: i=16272
# End: i=16272
# Start: i=16288
# End: i=16288
# Start: i=16304
# End: i=16304
# Start: i=16320
# End: i=16320
# Start: i=16336
# End: i=16336
# Start: i=16352
# End: i=16352
# Start: i=16368
# End: i=16368
# Start: i=16384
# End: i=16384
# Start: i=16400
# End: i=16400
# Start: i=16416
# End: i=16416
# Start: i=16432
# End: i=16432
# Start: i=16448
# End: i=16448
# Start: i=16464
# End: i=16464
# Start: i=16480
# End: i=16480
# Start: i=16496
# End: i=16496
# Start: i=16512
# End: i=16512
# Start: i=16528
# End: i=16528
# Start: i=16544
# End: i=16544
# Start: i=16560
# End: i=16560
# Start: i=16576
# End: i=16576
# Start: i=16592
# End: i=16592
# Start: i=16608
# End: i=16608
# Start: i=16624
# End: i=16624
# Start: i=16640
# End: i=16640
# Start: i=16656
# End: i=16656
# Start: i=16672
# End: i=16672
# Start: i=16688
# End: i=16688
# Start: i=16704
# End: i=16704
# Start: i=16720
# End: i=16720
# Start: i=16736
# End: i=16736
# Start: i=16752
# End: i=16752
# Start: i=16768
# End: i=16768
# Start: i=16784
# End: i=16784
# Start: i=16800
# End: i=16800
# Start: i=16816
# End: i=16816
# Start: i=16832
# End: i=16832
# Start: i=16848
# End: i=16848
# Start: i=16864
# End: i=16864
# Start: i=16880
# End: i=16880
# Start: i=16896
# End: i=16896
# Start: i=16912
# End: i=16912
# Start: i=16928
# End: i=16928
# Start: i=16944
# End: i=16944
# Start: i=16960
# End: i=16960
# Start: i=16976
# End: i=16976
# Start: i=16992
# End: i=16992
# Start: i=17008
# End: i=17008
# Start: i=17024
# End: i=17024
# Start: i=17040
# End: i=17040
# Start: i=17056
# End: i=17056
# Start: i=17072
# End: i=17072
# Start: i=17088
# End: i=17088
# Start: i=17104
# End: i=17104
# Start: i=17120
# End: i=17120
# Start: i=17136
# End: i=17136
# Start: i=17152
# End: i=17152
# Start: i=17168
# End: i=17168
# Start: i=17184
# End: i=17184
# Start: i=17200
# End: i=17200
# Start: i=17216
# End: i=17216
# Start: i=17232
# End: i=17232
# Start: i=17248
# End: i=17248
# Start: i=17264
# End: i=17264
# Start: i=17280
# End: i=17280
# Start: i=17296
# End: i=17296
# Start: i=17312
# End: i=17312
# Start: i=17328
# End: i=17328
# Start: i=17344
# End: i=17344
# Start: i=17360
# End: i=17360
# Start: i=17376
# End: i=17376
# Start: i=17392
# End: i=17392
# Start: i=17408
# End: i=17408
# Start: i=17424
# End: i=17424
# Start: i=17440
# End: i=17440
# Start: i=17456
# End: i=17456
# Start: i=17472
# End: i=17472
# Start: i=17488
# End: i=17488
# Start: i=17504
# End: i=17504
# Start: i=17520
# End: i=17520
# Start: i=17536
# End: i=17536
# Start: i=17552
# End: i=17552
# Start: i=17568
# End: i=17568
# Start: i=17584
# End: i=17584
# Start: i=17600
# End: i=17600
# Start: i=17616
# End: i=17616
# Start: i=17632
# End: i=17632
# Start: i=17648
# End: i=17648
# Start: i=17664
# End: i=17664
# Start: i=17680
# End: i=17680
# Start: i=17696
# End: i=17696
# Start: i=17712
# End: i=17712
# Start: i=17728
# End: i=17728
# Start: i=17744
# End: i=17744
# Start: i=17760
# End: i=17760
# Start: i=17776
# End: i=17776
# Start: i=17792
# End: i=17792
# Start: i=17808
# End: i=17808
# Start: i=17824
# End: i=17824
# Start: i=17840
# End: i=17840
# Start: i=17856
# End: i=17856
# Start: i=17872
# End: i=17872
# Start: i=17888
# End: i=17888
# Start: i=17904
# End: i=17904
# Start: i=17920
# End: i=17920
# Start: i=17936
# End: i=17936
# Start: i=17952
# End: i=17952
# Start: i=17968
# End: i=17968
# Start: i=17984
# End: i=17984
# Start: i=18000
# End: i=18000
# Start: i=18016
# End: i=18016
# Start: i=18032
# End: i=18032
# Start: i=18048
# End: i=18048
# Start: i=18064
# End: i=18064
# Start: i=18080
# End: i=18080
# Start: i=18096
# End: i=18096
# Start: i=18112
# End: i=18112
# Start: i=18128
# End: i=18128
# Start: i=18144
# End: i=18144
# Start: i=18160
# End: i=18160
# Start: i=18176
# End: i=18176
# Start: i=18192
# End: i=18192
# Start: i=18208
# End: i=18208
# Start: i=18224
# End: i=18224
# Start: i=18240
# End: i=18240
# Start: i=18256
# End: i=18256
# Start: i=18272
# End: i=18272
# Start: i=18288
# End: i=18288
# Start: i=18304
# End: i=18304
# Start: i=18320
# End: i=18320
# Start: i=18336
# End: i=18336
# Start: i=18352
# End: i=18352
# Start: i=18368
# End: i=18368
# Start: i=18384
# End: i=18384
# Start: i=18400
# End: i=18400
# Start: i=18416
# End: i=18416
# Start: i=18432
# End: i=18432
# Start: i=18448
# End: i=18448
# Start: i=18464
# End: i=18464
# Start: i=18480
# End: i=18480
# Start: i=18496
# End: i=18496
# Start: i=18512
# End: i=18512
# Start: i=18528
# End: i=18528
# Start: i=18544
# End: i=18544
# Start: i=18560
# End: i=18560
# Start: i=18576
# End: i=18576
# Start: i=18592
# End: i=18592
# Start: i=18608
# End: i=18608
# Start: i=18624
# End: i=18624
# Start: i=18640
# End: i=18640
# Start: i=18656
# End: i=18656
# Start: i=18672
# End: i=18672
# Start: i=18688
# End: i=18688
# Start: i=18704
# End: i=18704
# Start: i=18720
# End: i=18720
# Start: i=18736
# End: i=18736
# Start: i=18752
# End: i=18752
# Start: i=18768
# End: i=18768
# Start: i=18784
# End: i=18784
# Start: i=18800
# End: i=18800
# Start: i=18816
# End: i=18816
# Start: i=18832
# End: i=18832
# Start: i=18848
# End: i=18848
# Start: i=18864
# End: i=18864
# Start: i=18880
# End: i=18880
# Start: i=18896
# End: i=18896
# Start: i=18912
# End: i=18912
# Start: i=18928
# End: i=18928
# Start: i=18944
# End: i=18944
# Start: i=18960
# End: i=18960
# Start: i=18976
# End: i=18976
# Start: i=18992
# End: i=18992
# Start: i=19008
# End: i=19008
# Start: i=19024
# End: i=19024
# Start: i=19040
# End: i=19040
# Start: i=19056
# End: i=19056
# Start: i=19072
# End: i=19072
# Start: i=19088
# End: i=19088
# Start: i=19104
# End: i=19104
# Start: i=19120
# End: i=19120
# Start: i=19136
# End: i=19136
# Start: i=19152
# End: i=19152
# Start: i=19168
# End: i=19168
# Start: i=19184
# End: i=19184
# Start: i=19200
# End: i=19200
# Start: i=19216
# End: i=19216
# Start: i=19232
# End: i=19232
# Start: i=19248
# End: i=19248
# Start: i=19264
# End: i=19264
# Start: i=19280
# End: i=19280
# Start: i=19296
# End: i=19296
# Start: i=19312
# End: i=19312
# Start: i=19328
# End: i=19328
# Start: i=19344
# End: i=19344
# Start: i=19360
# End: i=19360
# Start: i=19376
# End: i=19376
# Start: i=19392
# End: i=19392
# Start: i=19408
# End: i=19408
# Start: i=19424
# End: i=19424
# Start: i=19440
# End: i=19440
# Start: i=19456
# End: i=19456
# Start: i=19472
# End: i=19472
# Start: i=19488
# End: i=19488
# Start: i=19504
# End: i=19504
# Start: i=19520
# End: i=19520
# Start: i=19536
# End: i=19536
# Start: i=19552
# End: i=19552
# Start: i=19568
# End: i=19568
# Start: i=19584
# End: i=19584
# Start: i=19600
# End: i=19600
# Start: i=19616
# End: i=19616
# Start: i=19632
# End: i=19632
# Start: i=19648
# End: i=19648
# Start: i=19664
# End: i=19664
# Start: i=19680
# End: i=19680
# Start: i=19696
# End: i=19696
# Start: i=19712
# End: i=19712
# Start: i=19728
# End: i=19728
# Start: i=19744
# End: i=19744
# Start: i=19760
# End: i=19760
# Start: i=19776
# End: i=19776
# Start: i=19792
# End: i=19792
# Start: i=19808
# End: i=19808
# Start: i=19824
# End: i=19824
# Start: i=19840
# End: i=19840
# Start: i=19856
# End: i=19856
# Start: i=19872
# End: i=19872
# Start: i=19888
# End: i=19888
# Start: i=19904
# End: i=19904
# Start: i=19920
# End: i=19920
# Start: i=19936
# End: i=19936
# Start: i=19952
# End: i=19952
# Start: i=19968
# End: i=19968
# Start: i=19984
# End: i=19984
# Start: i=20000
# End: i=20000
# Start: i=20016
# End: i=20016
# Start: i=20032
# End: i=20032
# Start: i=20048
# End: i=20048
# Start: i=20064
# End: i=20064
# Start: i=20080
# End: i=20080
# Start: i=20096
# End: i=20096
# Start: i=20112
# End: i=20112
# Start: i=20128
# End: i=20128
# Start: i=20144
# End: i=20144
# Start: i=20160
# End: i=20160
# Start: i=20176
# End: i=20176
# Start: i=20192
# End: i=20192
# Start: i=20208
# End: i=20208
# Start: i=20224
# End: i=20224
# Start: i=20240
# End: i=20240
# Start: i=20256
# End: i=20256
# Start: i=20272
# End: i=20272
# Start: i=20288
# End: i=20288
# Start: i=20304
# End: i=20304
# Start: i=20320
# End: i=20320
# Start: i=20336
# End: i=20336
# Start: i=20352
# End: i=20352
# Start: i=20368
# End: i=20368
# Start: i=20384
# End: i=20384
# Start: i=20400
# End: i=20400
# Start: i=20416
# End: i=20416
# Start: i=20432
# End: i=20432
# Start: i=20448
# End: i=20448
# Start: i=20464
# End: i=20464
# Start: i=20480
# End: i=20480
# Start: i=20496
# End: i=20496
# Start: i=20512
# End: i=20512
# Start: i=20528
# End: i=20528
# Start: i=20544
# End: i=20544
# Start: i=20560
# End: i=20560
# Start: i=20576
# End: i=20576
# Start: i=20592
# End: i=20592
# Start: i=20608
# End: i=20608
# Start: i=20624
# End: i=20624
# Start: i=20640
# End: i=20640
# Start: i=20656
# End: i=20656
# Start: i=20672
# End: i=20672
# Start: i=20688
# End: i=20688
# Start: i=20704
# End: i=20704
# Start: i=20720
# End: i=20720
# Start: i=20736
# End: i=20736
# Start: i=20752
# End: i=20752
# Start: i=20768
# End: i=20768
# Start: i=20784
# End: i=20784
# Start: i=20800
# End: i=20800
# Start: i=20816
# End: i=20816
# Start: i=20832
# End: i=20832
# Start: i=20848
# End: i=20848
# Start: i=20864
# End: i=20864
# Start: i=20880
# End: i=20880
# Start: i=20896
# End: i=20896
# Start: i=20912
# End: i=20912
# Start: i=20928
# End: i=20928
# Start: i=20944
# End: i=20944
# Start: i=20960
# End: i=20960
# Start: i=20976
# End: i=20976
# Start: i=20992
# End: i=20992
# Start: i=21008
# End: i=21008
# Start: i=21024
# End: i=21024
# Start: i=21040
# End: i=21040
# Start: i=21056
# End: i=21056
# Start: i=21072
# End: i=21072
# Start: i=21088
# End: i=21088
# Start: i=21104
# End: i=21104
# Start: i=21120
# End: i=21120
# Start: i=21136
# End: i=21136
# Start: i=21152
# End: i=21152
# Start: i=21168
# End: i=21168
# Start: i=21184
# End: i=21184
# Start: i=21200
# End: i=21200
# Start: i=21216
# End: i=21216
# Start: i=21232
# End: i=21232
# Start: i=21248
# End: i=21248
# Start: i=21264
# End: i=21264
# Start: i=21280
# End: i=21280
# Start: i=21296
# End: i=21296
# Start: i=21312
# End: i=21312
# Start: i=21328
# End: i=21328
# Start: i=21344
# End: i=21344
# Start: i=21360
# End: i=21360
# Start: i=21376
# End: i=21376
# Start: i=21392
# End: i=21392
# Start: i=21408
# End: i=21408
# Start: i=21424
# End: i=21424
# Start: i=21440
# End: i=21440
# Start: i=21456
# End: i=21456
# Start: i=21472
# End: i=21472
# Start: i=21488
# End: i=21488
# Start: i=21504
# End: i=21504
# Start: i=21520
# End: i=21520
# Start: i=21536
# End: i=21536
# Start: i=21552
# End: i=21552
# Start: i=21568
# End: i=21568
# Start: i=21584
# End: i=21584
# Start: i=21600
# End: i=21600
# Start: i=21616
# End: i=21616
# Start: i=21632
# End: i=21632
# Start: i=21648
# End: i=21648
# Start: i=21664
# End: i=21664
# Start: i=21680
# End: i=21680
# Start: i=21696
# End: i=21696
# Start: i=21712
# End: i=21712
# Start: i=21728
# End: i=21728
# Start: i=21744
# End: i=21744
# Start: i=21760
# End: i=21760
# Start: i=21776
# End: i=21776
# Start: i=21792
# End: i=21792
# Start: i=21808
# End: i=21808
# Start: i=21824
# End: i=21824
# Start: i=21840
# End: i=21840
# Start: i=21856
# End: i=21856
# Start: i=21872
# End: i=21872
# Start: i=21888
# End: i=21888
# Start: i=21904
# End: i=21904
# Start: i=21920
# End: i=21920
# Start: i=21936
# End: i=21936
# Start: i=21952
# End: i=21952
# Start: i=21968
# End: i=21968
# Start: i=21984
# End: i=21984
# Start: i=22000
# End: i=22000
# Start: i=22016
# End: i=22016
# Start: i=22032
# End: i=22032
# Start: i=22048
# End: i=22048
# Start: i=22064
# End: i=22064
# Start: i=22080
# End: i=22080
# Start: i=22096
# End: i=22096
# Start: i=22112
# End: i=22112
# Start: i=22128
# End: i=22128
# Start: i=22144
# End: i=22144
# Start: i=22160
# End: i=22160
# Start: i=22176
# End: i=22176
# Start: i=22192
# End: i=22192
# Start: i=22208
# End: i=22208
# Start: i=22224
# End: i=22224
# Start: i=22240
# End: i=22240
# Start: i=22256
# End: i=22256
# Start: i=22272
# End: i=22272
# Start: i=22288
# End: i=22288
# Start: i=22304
# End: i=22304
# Start: i=22320
# End: i=22320
# Start: i=22336
# End: i=22336
# Start: i=22352
# End: i=22352
# Start: i=22368
# End: i=22368
# Start: i=22384
# End: i=22384
# Start: i=22400
# End: i=22400
# Start: i=22416
# End: i=22416
# Start: i=22432
# End: i=22432
# Start: i=22448
# End: i=22448
# Start: i=22464
# End: i=22464
# Start: i=22480
# End: i=22480
# Start: i=22496
# End: i=22496
# Start: i=22512
# End: i=22512
# Start: i=22528
# End: i=22528
# Start: i=22544
# End: i=22544
# Start: i=22560
# End: i=22560
# Start: i=22576
# End: i=22576
# Start: i=22592
# End: i=22592
# Start: i=22608
# End: i=22608
# Start: i=22624
# End: i=22624
# Start: i=22640
# End: i=22640
# Start: i=22656
# End: i=22656
# Start: i=22672
# End: i=22672
# Start: i=22688
# End: i=22688
# Start: i=22704
# End: i=22704
# Start: i=22720
# End: i=22720
# Start: i=22736
# End: i=22736
# Start: i=22752
# End: i=22752
# Start: i=22768
# End: i=22768
# Start: i=22784
# End: i=22784
# Start: i=22800
# End: i=22800
# Start: i=22816
# End: i=22816
# Start: i=22832
# End: i=22832
# Start: i=22848
# End: i=22848
# Start: i=22864
# End: i=22864
# Start: i=22880
# End: i=22880
# Start: i=22896
# End: i=22896
# Start: i=22912
# End: i=22912
# Start: i=22928
# End: i=22928
# Start: i=22944
# End: i=22944
# Start: i=22960
# End: i=22960
# Start: i=22976
# End: i=22976
# Start: i=22992
# End: i=22992
# Start: i=23008
# End: i=23008
# Start: i=23024
# End: i=23024
# Start: i=23040
# End: i=23040
# Start: i=23056
# End: i=23056
# Start: i=23072
# End: i=23072
# Start: i=23088
# End: i=23088
# Start: i=23104
# End: i=23104
# Start: i=23120
# End: i=23120
# Start: i=23136
# End: i=23136
# Start: i=23152
# End: i=23152
# Start: i=23168
# End: i=23168
# Start: i=23184
# End: i=23184
# Start: i=23200
# End: i=23200
# Start: i=23216
# End: i=23216
# Start: i=23232
# End: i=23232
# Start: i=23248
# End: i=23248
# Start: i=23264
# End: i=23264
# Start: i=23280
# End: i=23280
# Start: i=23296
# End: i=23296
# Start: i=23312
# End: i=23312
# Start: i=23328
# End: i=23328
# Start: i=23344
# End: i=23344
# Start: i=23360
# End: i=23360
# Start: i=23376
# End: i=23376
# Start: i=23392
# End: i=23392
# Start: i=23408
# End: i=23408
# Start: i=23424
# End: i=23424
# Start: i=23440
# End: i=23440
# Start: i=23456
# End: i=23456
# Start: i=23472
# End: i=23472
# Start: i=23488
# End: i=23488
# Start: i=23504
# End: i=23504
# Start: i=23520
# End: i=23520
# Start: i=23536
# End: i=23536
# Start: i=23552
# End: i=23552
# Start: i=23568
# End: i=23568
# Start: i=23584
# End: i=23584
# Start: i=23600
# End: i=23600
# Start: i=23616
# End: i=23616
# Start: i=23632
# End: i=23632
# Start: i=23648
# End: i=23648
# Start: i=23664
# End: i=23664
# Start: i=23680
# End: i=23680
# Start: i=23696
# End: i=23696
# Start: i=23712
# End: i=23712
# Start: i=23728
# End: i=23728
# Start: i=23744
# End: i=23744
# Start: i=23760
# End: i=23760
# Start: i=23776
# End: i=23776
# Start: i=23792
# End: i=23792
# Start: i=23808
# End: i=23808
# Start: i=23824
# End: i=23824
# Start: i=23840
# End: i=23840
# Start: i=23856
# End: i=23856
# Start: i=23872
# End: i=23872
# Start: i=23888
# End: i=23888
# Start: i=23904
# End: i=23904
# Start: i=23920
# End: i=23920
# Start: i=23936
# End: i=23936
# Start: i=23952
# End: i=23952
# Start: i=23968
# End: i=23968
# Start: i=23984
# End: i=23984
# Start: i=24000
# End: i=24000
# Start: i=24016
# End: i=24016
# Start: i=24032
# End: i=24032
# Start: i=24048
# End: i=24048
# Start: i=24064
# End: i=24064
# Start: i=24080
# End: i=24080
# Start: i=24096
# End: i=24096
# Start: i=24112
# End: i=24112
# Start: i=24128
# End: i=24128
# Start: i=24144
# End: i=24144
# Start: i=24160
# End: i=24160
# Start: i=24176
# End: i=24176
# Start: i=24192
# End: i=24192
# Start: i=24208
# End: i=24208
# Start: i=24224
# End: i=24224
# Start: i=24240
# End: i=24240
# Start: i=24256
# End: i=24256
# Start: i=24272
# End: i=24272
# Start: i=24288
# End: i=24288
# Start: i=24304
# End: i=24304
# Start: i=24320
# End: i=24320
# Start: i=24336
# End: i=24336
# Start: i=24352
# End: i=24352
# Start: i=24368
# End: i=24368
# Start: i=24384
# End: i=24384
# Start: i=24400
# End: i=24400
# Start: i=24416
# End: i=24416
# Start: i=24432
# End: i=24432
# Start: i=24448
# End: i=24448
# Start: i=24464
# End: i=24464
# Start: i=24480
# End: i=24480
# Start: i=24496
# End: i=24496
# Start: i=24512
# End: i=24512
# Start: i=24528
# End: i=24528
# Start: i=24544
# End: i=24544
# Start: i=24560
# End: i=24560
# Start: i=24576
# End: i=24576
# Start: i=24592
# End: i=24592
# Start: i=24608
# End: i=24608
# Start: i=24624
# End: i=24624
# Start: i=24640
# End: i=24640
# Start: i=24656
# End: i=24656
# Start: i=24672
# End: i=24672
# Start: i=24688
# End: i=24688
# Start: i=24704
# End: i=24704
# Start: i=24720
# End: i=24720
# Start: i=24736
# End: i=24736
# Start: i=24752
# End: i=24752
# Start: i=24768
# End: i=24768
# Start: i=24784
# End: i=24784
# Start: i=24800
# End: i=24800
# Start: i=24816
# End: i=24816
# Start: i=24832
# End: i=24832
# Start: i=24848
# End: i=24848
# Start: i=24864
# End: i=24864
# Start: i=24880
# End: i=24880
# Start: i=24896
# End: i=24896
# Start: i=24912
# End: i=24912
# Start: i=24928
# End: i=24928
# Start: i=24944
# End: i=24944
# Start: i=24960
# End: i=24960
# Start: i=24976
# End: i=24976
# Start: i=24992
# End: i=24992
# Start: i=25008
# End: i=25008
# Start: i=25024
# End: i=25024
# Start: i=25040
# End: i=25040
# Start: i=25056
# End: i=25056
# Start: i=25072
# End: i=25072
# Start: i=25088
# End: i=25088
# Start: i=25104
# End: i=25104
# Start: i=25120
# End: i=25120
# Start: i=25136
# End: i=25136
# Start: i=25152
# End: i=25152
# Start: i=25168
# End: i=25168
# Start: i=25184
# End: i=25184
# Start: i=25200
# End: i=25200
# Start: i=25216
# End: i=25216
# Start: i=25232
# End: i=25232
# Start: i=25248
# End: i=25248
# Start: i=25264
# End: i=25264
# Start: i=25280
# End: i=25280
# Start: i=25296
# End: i=25296
# Start: i=25312
# End: i=25312
# Start: i=25328
# End: i=25328
# Start: i=25344
# End: i=25344
# Start: i=25360
# End: i=25360
# Start: i=25376
# End: i=25376
# Start: i=25392
# End: i=25392
# Start: i=25408
# End: i=25408
# Start: i=25424
# End: i=25424
# Start: i=25440
# End: i=25440
# Start: i=25456
# End: i=25456
# Start: i=25472
# End: i=25472
# Start: i=25488
# End: i=25488
# Start: i=25504
# End: i=25504
# Start: i=25520
# End: i=25520
# Start: i=25536
# End: i=25536
# Start: i=25552
# End: i=25552
# Start: i=25568
# End: i=25568
# Start: i=25584
# End: i=25584
# Start: i=25600
# End: i=25600
# Start: i=25616
# End: i=25616
# Start: i=25632
# End: i=25632
# Start: i=25648
# End: i=25648
# Start: i=25664
# End: i=25664
# Start: i=25680
# End: i=25680
# Start: i=25696
# End: i=25696
# Start: i=25712
# End: i=25712
# Start: i=25728
# End: i=25728
# Start: i=25744
# End: i=25744
# Start: i=25760
# End: i=25760
# Start: i=25776
# End: i=25776
# Start: i=25792
# End: i=25792
# Start: i=25808
# End: i=25808
# Start: i=25824
# End: i=25824
# Start: i=25840
# End: i=25840
# Start: i=25856
# End: i=25856
# Start: i=25872
# End: i=25872
# Start: i=25888
# End: i=25888
# Start: i=25904
# End: i=25904
# Start: i=25920
# End: i=25920
# Start: i=25936
# End: i=25936
# Start: i=25952
# End: i=25952
# Start: i=25968
# End: i=25968
# Start: i=25984
# End: i=25984
# Start: i=26000
# End: i=26000
# Start: i=26016
# End: i=26016
# Start: i=26032
# End: i=26032
# Start: i=26048
# End: i=26048
# Start: i=26064
# End: i=26064
# Start: i=26080
# End: i=26080
# Start: i=26096
# End: i=26096
# Start: i=26112
# End: i=26112
# Start: i=26128
# End: i=26128
# Start: i=26144
# End: i=26144
# Start: i=26160
# End: i=26160
# Start: i=26176
# End: i=26176
# Start: i=26192
# End: i=26192
# Start: i=26208
# End: i=26208
# Start: i=26224
# End: i=26224
# Start: i=26240
# End: i=26240
# Start: i=26256
# End: i=26256
# Start: i=26272
# End: i=26272
# Start: i=26288
# End: i=26288
# Start: i=26304
# End: i=26304
# Start: i=26320
# End: i=26320
# Start: i=26336
# End: i=26336
# Start: i=26352
# End: i=26352
# Start: i=26368
# End: i=26368
# Start: i=26384
# End: i=26384
# Start: i=26400
# End: i=26400
# Start: i=26416
# End: i=26416
# Start: i=26432
# End: i=26432
# Start: i=26448
# End: i=26448
# Start: i=26464
# End: i=26464
# Start: i=26480
# End: i=26480
# Start: i=26496
# End: i=26496
# Start: i=26512
# End: i=26512
# Start: i=26528
# End: i=26528
# Start: i=26544
# End: i=26544
# Start: i=26560
# End: i=26560
# Start: i=26576
# End: i=26576
# Start: i=26592
# End: i=26592
# Start: i=26608
# End: i=26608
# Start: i=26624
# End: i=26624
# Start: i=26640
# End: i=26640
# Start: i=26656
# End: i=26656
# Start: i=26672
# End: i=26672
# Start: i=26688
# End: i=26688
# Start: i=26704
# End: i=26704
# Start: i=26720
# End: i=26720
# Start: i=26736
# End: i=26736
# Start: i=26752
# End: i=26752
# Start: i=26768
# End: i=26768
# Start: i=26784
# End: i=26784
# Start: i=26800
# End: i=26800
# Start: i=26816
# End: i=26816
# Start: i=26832
# End: i=26832
# Start: i=26848
# End: i=26848
# Start: i=26864
# End: i=26864
# Start: i=26880
# End: i=26880
# Start: i=26896
# End: i=26896
# Start: i=26912
# End: i=26912
# Start: i=26928
# End: i=26928
# Start: i=26944
# End: i=26944
# Start: i=26960
# End: i=26960
# Start: i=26976
# End: i=26976
# Start: i=26992
# End: i=26992
# Start: i=27008
# End: i=27008
# Start: i=27024
# End: i=27024
# Start: i=27040
# End: i=27040
# Start: i=27056
# End: i=27056
# Start: i=27072
# End: i=27072
# Start: i=27088
# End: i=27088
# Start: i=27104
# End: i=27104
# Start: i=27120
# End: i=27120
# Start: i=27136
# End: i=27136
# Start: i=27152
# End: i=27152
# Start: i=27168
# End: i=27168
# Start: i=27184
# End: i=27184
# Start: i=27200
# End: i=27200
# Start: i=27216
# End: i=27216
# Start: i=27232
# End: i=27232
# Start: i=27248
# End: i=27248
# Start: i=27264
# End: i=27264
# Start: i=27280
# End: i=27280
# Start: i=27296
# End: i=27296
# Start: i=27312
# End: i=27312
# Start: i=27328
# End: i=27328
# Start: i=27344
# End: i=27344
# Start: i=27360
# End: i=27360
# Start: i=27376
# End: i=27376
# Start: i=27392
# End: i=27392
# Start: i=27408
# End: i=27408
# Start: i=27424
# End: i=27424
# Start: i=27440
# End: i=27440
# Start: i=27456
# End: i=27456
# Start: i=27472
# End: i=27472
# Start: i=27488
# End: i=27488
# Start: i=27504
# End: i=27504
# Start: i=27520
# End: i=27520
# Start: i=27536
# End: i=27536
# Start: i=27552
# End: i=27552
# Start: i=27568
# End: i=27568
# Start: i=27584
# End: i=27584
# Start: i=27600
# End: i=27600
# Start: i=27616
# End: i=27616
# Start: i=27632
# End: i=27632
# Start: i=27648
# End: i=27648
# Start: i=27664
# End: i=27664
# Start: i=27680
# End: i=27680
# Start: i=27696
# End: i=27696
# Start: i=27712
# End: i=27712
# Start: i=27728
# End: i=27728
# Start: i=27744
# End: i=27744
# Start: i=27760
# End: i=27760
# Start: i=27776
# End: i=27776
# Start: i=27792
# End: i=27792
# Start: i=27808
# End: i=27808
# Start: i=27824
# End: i=27824
# Start: i=27840
# End: i=27840
# Start: i=27856
# End: i=27856
# Start: i=27872
# End: i=27872
# Start: i=27888
# End: i=27888
# Start: i=27904
# End: i=27904
# Start: i=27920
# End: i=27920
# Start: i=27936
# End: i=27936
# Start: i=27952
# End: i=27952
# Start: i=27968
# End: i=27968
# Start: i=27984
# End: i=27984
# Start: i=28000
# End: i=28000
# Start: i=28016
# End: i=28016
# Start: i=28032
# End: i=28032
# Start: i=28048
# End: i=28048
# Start: i=28064
# End: i=28064
# Start: i=28080
# End: i=28080
# Start: i=28096
# End: i=28096
# Start: i=28112
# End: i=28112
# Start: i=28128
# End: i=28128
# Start: i=28144
# End: i=28144
# Start: i=28160
# End: i=28160
# Start: i=28176
# End: i=28176
# Start: i=28192
# End: i=28192
# Start: i=28208
# End: i=28208
# Start: i=28224
# End: i=28224
# Start: i=28240
# End: i=28240
# Start: i=28256
# End: i=28256
# Start: i=28272
# End: i=28272
# Start: i=28288
# End: i=28288
# Start: i=28304
# End: i=28304
# Start: i=28320
# End: i=28320
# Start: i=28336
# End: i=28336
# Start: i=28352
# End: i=28352
# Start: i=28368
# End: i=28368
# Start: i=28384
# End: i=28384
# Start: i=28400
# End: i=28400
# Start: i=28416
# End: i=28416
# Start: i=28432
# End: i=28432
# Start: i=28448
# End: i=28448
# Start: i=28464
# End: i=28464
# Start: i=28480
# End: i=28480
# Start: i=28496
# End: i=28496
# Start: i=28512
# End: i=28512
# Start: i=28528
# End: i=28528
# Start: i=28544
# End: i=28544
# Start: i=28560
# End: i=28560
# Start: i=28576
# End: i=28576
# Start: i=28592
# End: i=28592
# Start: i=28608
# End: i=28608
# Start: i=28624
# End: i=28624
# Start: i=28640
# End: i=28640
# Start: i=28656
# End: i=28656
# Start: i=28672
# End: i=28672
# Start: i=28688
# End: i=28688
# Start: i=28704
# End: i=28704
# Start: i=28720
# End: i=28720
# Start: i=28736
# End: i=28736
# Start: i=28752
# End: i=28752
# Start: i=28768
# End: i=28768
# Start: i=28784
# End: i=28784
# Start: i=28800
# End: i=28800
# Start: i=28816
# End: i=28816
# Start: i=28832
# End: i=28832
# Start: i=28848
# End: i=28848
# Start: i=28864
# End: i=28864
# Start: i=28880
# End: i=28880
# Start: i=28896
# End: i=28896
# Start: i=28912
# End: i=28912
# Start: i=28928
# End: i=28928
# Start: i=28944
# End: i=28944
# Start: i=28960
# End: i=28960
# Start: i=28976
# End: i=28976
# Start: i=28992
# End: i=28992
# Start: i=29008
# End: i=29008
# Start: i=29024
# End: i=29024
# Start: i=29040
# End: i=29040
# Start: i=29056
# End: i=29056
# Start: i=29072
# End: i=29072
# Start: i=29088
# End: i=29088
# Start: i=29104
# End: i=29104
# Start: i=29120
# End: i=29120
# Start: i=29136
# End: i=29136
# Start: i=29152
# End: i=29152
# Start: i=29168
# End: i=29168
# Start: i=29184
# End: i=29184
# Start: i=29200
# End: i=29200
# Start: i=29216
# End: i=29216
# Start: i=29232
# End: i=29232
# Start: i=29248
# End: i=29248
# Start: i=29264
# End: i=29264
# Start: i=29280
# End: i=29280
# Start: i=29296
# End: i=29296
# Start: i=29312
# End: i=29312
# Start: i=29328
# End: i=29328
# Start: i=29344
# End: i=29344
# Start: i=29360
# End: i=29360
# Start: i=29376
# End: i=29376
# Start: i=29392
# End: i=29392
# Start: i=29408
# End: i=29408
# Start: i=29424
# End: i=29424
# Start: i=29440
# End: i=29440
# Start: i=29456
# End: i=29456
# Start: i=29472
# End: i=29472
# Start: i=29488
# End: i=29488
# Start: i=29504
# End: i=29504
# Start: i=29520
# End: i=29520
# Start: i=29536
# End: i=29536
# Start: i=29552
# End: i=29552
# Start: i=29568
# End: i=29568
# Start: i=29584
# End: i=29584
# Start: i=29600
# End: i=29600
# Start: i=29616
# End: i=29616
# Start: i=29632
# End: i=29632
# Start: i=29648
# End: i=29648
# Start: i=29664
# End: i=29664
# Start: i=29680
# End: i=29680
# Start: i=29696
# End: i=29696
# Start: i=29712
# End: i=29712
# Start: i=29728
# End: i=29728
# Start: i=29744
# End: i=29744
# Start: i=29760
# End: i=29760
# Start: i=29776
# End: i=29776
# Start: i=29792
# End: i=29792
# Start: i=29808
# End: i=29808
# Start: i=29824
# End: i=29824
# Start: i=29840
# End: i=29840
# Start: i=29856
# End: i=29856
# Start: i=29872
# End: i=29872
# Start: i=29888
# End: i=29888
# Start: i=29904
# End: i=29904
# Start: i=29920
# End: i=29920
# Start: i=29936
# End: i=29936
# Start: i=29952
# End: i=29952
# Start: i=29968
# End: i=29968
# Start: i=29984
# End: i=29984
# Start: i=30000
# End: i=30000
# Start: i=30016
# End: i=30016
# Start: i=30032
# End: i=30032
# Start: i=30048
# End: i=30048
# Start: i=30064
# End: i=30064
# Start: i=30080
# End: i=30080
# Start: i=30096
# End: i=30096
# Start: i=30112
# End: i=30112
# Start: i=30128
# End: i=30128
# Start: i=30144
# End: i=30144
# Start: i=30160
# End: i=30160
# Start: i=30176
# End: i=30176
# Start: i=30192
# End: i=30192
# Start: i=30208
# End: i=30208
# Start: i=30224
# End: i=30224
# Start: i=30240
# End: i=30240
# Start: i=30256
# End: i=30256
# Start: i=30272
# End: i=30272
# Start: i=30288
# End: i=30288
# Start: i=30304
# End: i=30304
# Start: i=30320
# End: i=30320
# Start: i=30336
# End: i=30336
# Start: i=30352
# End: i=30352
# Start: i=30368
# End: i=30368
# Start: i=30384
# End: i=30384
# Start: i=30400
# End: i=30400
# Start: i=30416
# End: i=30416
# Start: i=30432
# End: i=30432
# Start: i=30448
# End: i=30448
# Start: i=30464
# End: i=30464
# Start: i=30480
# End: i=30480
# Start: i=30496
# End: i=30496
# Start: i=30512
# End: i=30512
# Start: i=30528
# End: i=30528
# Start: i=30544
# End: i=30544
# Start: i=30560
# End: i=30560
# Start: i=30576
# End: i=30576
# Start: i=30592
# End: i=30592
# Start: i=30608
# End: i=30608
# Start: i=30624
# End: i=30624
# Start: i=30640
# End: i=30640
# Start: i=30656
# End: i=30656
# Start: i=30672
# End: i=30672
# Start: i=30688
# End: i=30688
# Start: i=30704
# End: i=30704
# Start: i=30720
# End: i=30720
# Start: i=30736
# End: i=30736
# Start: i=30752
# End: i=30752
# Start: i=30768
# End: i=30768
# Start: i=30784
# End: i=30784
# Start: i=30800
# End: i=30800
# Start: i=30816
# End: i=30816
# Start: i=30832
# End: i=30832
# Start: i=30848
# End: i=30848
# Start: i=30864
# End: i=30864
# Start: i=30880
# End: i=30880
# Start: i=30896
# End: i=30896
# Start: i=30912
# End: i=30912
# Start: i=30928
# End: i=30928
# Start: i=30944
# End: i=30944
# Start: i=30960
# End: i=30960
# Start: i=30976
# End: i=30976
# Start: i=30992
# End: i=30992
# Start: i=31008
# End: i=31008
# Start: i=31024
# End: i=31024
# Start: i=31040
# End: i=31040
# Start: i=31056
# End: i=31056
# Start: i=31072
# End: i=31072
# Start: i=31088
# End: i=31088
# Start: i=31104
# End: i=31104
# Start: i=31120
# End: i=31120
# Start: i=31136
# End: i=31136
# Start: i=31152
# End: i=31152
# Start: i=31168
# End: i=31168
# Start: i=31184
# End: i=31184
# Start: i=31200
# End: i=31200
# Start: i=31216
# End: i=31216
# Start: i=31232
# End: i=31232
# Start: i=31248
# End: i=31248
# Start: i=31264
# End: i=31264
# Start: i=31280
# End: i=31280
# Start: i=31296
# End: i=31296
# Start: i=31312
# End: i=31312
# Start: i=31328
# End: i=31328
# Start: i=31344
# End: i=31344
# Start: i=31360
# End: i=31360
# Start: i=31376
# End: i=31376
# Start: i=31392
# End: i=31392
# Start: i=31408
# End: i=31408
# Start: i=31424
# End: i=31424
# Start: i=31440
# End: i=31440
# Start: i=31456
# End: i=31456
# Start: i=31472
# End: i=31472
# Start: i=31488
# End: i=31488
# Start: i=31504
# End: i=31504
# Start: i=31520
# End: i=31520
# Start: i=31536
# End: i=31536
# Start: i=31552
# End: i=31552
# Start: i=31568
# End: i=31568
# Start: i=31584
# End: i=31584
# Start: i=31600
# End: i=31600
# Start: i=31616
# End: i=31616
# Start: i=31632
# End: i=31632
# Start: i=31648
# End: i=31648
# Start: i=31664
# End: i=31664
# Start: i=31680
# End: i=31680
# Start: i=31696
# End: i=31696
# Start: i=31712
# End: i=31712
# Start: i=31728
# End: i=31728
# Start: i=31744
# End: i=31744
# Start: i=31760
# End: i=31760
# Start: i=31776
# End: i=31776
# Start: i=31792
# End: i=31792
# Start: i=31808
# End: i=31808
# Start: i=31824
# End: i=31824
# Start: i=31840
# End: i=31840
# Start: i=31856
# End: i=31856
# Start: i=31872
# End: i=31872
# Start: i=31888
# End: i=31888
# Start: i=31904
# End: i=31904
# Start: i=31920
# End: i=31920
# Start: i=31936
# End: i=31936
# Start: i=31952
# End: i=31952
# Start: i=31968
# End: i=31968
# Start: i=31984
# End: i=31984
# Start: i=32000
# End: i=32000
# Start: i=32016
# End: i=32016
# Start: i=32032
# End: i=32032
# Start: i=32048
# End: i=32048
# Start: i=32064
# End: i=32064
# Start: i=32080
# End: i=32080
# Start: i=32096
# End: i=32096
# Start: i=32112
# End: i=32112
# Start: i=32128
# End: i=32128
# Start: i=32144
# End: i=32144
# Start: i=32160
# End: i=32160
# Start: i=32176
# End: i=32176
# Start: i=32192
# End: i=32192
# Start: i=32208
# End: i=32208
# Start: i=32224
# End: i=32224
# Start: i=32240
# End: i=32240
# Start: i=32256
# End: i=32256
# Start: i=32272
# End: i=32272
# Start: i=32288
# End: i=32288
# Start: i=32304
# End: i=32304
# Start: i=32320
# End: i=32320
# Start: i=32336
# End: i=32336
# Start: i=32352
# End: i=32352
# Start: i=32368
# End: i=32368
# Start: i=32384
# End: i=32384
# Start: i=32400
# End: i=32400
# Start: i=32416
# End: i=32416
# Start: i=32432
# End: i=32432
# Start: i=32448
# End: i=32448
# Start: i=32464
# End: i=32464
# Start: i=32480
# End: i=32480
# Start: i=32496
# End: i=32496
# Start: i=32512
# End: i=32512
# Start: i=32528
# End: i=32528
# Start: i=32544
# End: i=32544
# Start: i=32560
# End: i=32560
# Start: i=32576
# End: i=32576
# Start: i=32592
# End: i=32592
# Start: i=32608
# End: i=32608
# Start: i=32624
# End: i=32624
# Start: i=32640
# End: i=32640
# Start: i=32656
# End: i=32656
# Start: i=32672
# End: i=32672
# Start: i=32688
# End: i=32688
# Start: i=32704
# End: i=32704
# Start: i=32720
# End: i=32720
# Start: i=32736
# End: i=32736
# Start: i=32752
# End: i=32752
# Start: i=32768
# End: i=32768
# Start: i=32784
# End: i=32784
# Start: i=32800
# End: i=32800
# Start: i=32816
# End: i=32816
# Start: i=32832
# End: i=32832
# Start: i=32848
# End: i=32848
# Start: i=32864
# End: i=32864
# Start: i=32880
# End: i=32880
# Start: i=32896
# End: i=32896
# Start: i=32912
# End: i=32912
# Start: i=32928
# End: i=32928
# Start: i=32944
# End: i=32944
# Start: i=32960
# End: i=32960
# Start: i=32976
# End: i=32976
# Start: i=32992
# End: i=32992
# Start: i=33008
# End: i=33008
# Start: i=33024
# End: i=33024
# Start: i=33040
# End: i=33040
# Start: i=33056
# End: i=33056
# Start: i=33072
# End: i=33072
# Start: i=33088
# End: i=33088
# Start: i=33104
# End: i=33104
# Start: i=33120
# End: i=33120
# Start: i=33136
# End: i=33136
# Start: i=33152
# End: i=33152
# Start: i=33168
# End: i=33168
# Start: i=33184
# End: i=33184
# Start: i=33200
# End: i=33200
# Start: i=33216
# End: i=33216
# Start: i=33232
# End: i=33232
# Start: i=33248
# End: i=33248
# Start: i=33264
# End: i=33264
# Start: i=33280
# End: i=33280
# Start: i=33296
# End: i=33296
# Start: i=33312
# End: i=33312
# Start: i=33328
# End: i=33328
# Start: i=33344
# End: i=33344
# Start: i=33360
# End: i=33360
# Start: i=33376
# End: i=33376
# Start: i=33392
# End: i=33392
# Start: i=33408
# End: i=33408
# Start: i=33424
# End: i=33424
# Start: i=33440
# End: i=33440
# Start: i=33456
# End: i=33456
# Start: i=33472
# End: i=33472
# Start: i=33488
# End: i=33488
# Start: i=33504
# End: i=33504
# Start: i=33520
# End: i=33520
# Start: i=33536
# End: i=33536
# Start: i=33552
# End: i=33552
# Start: i=33568
# End: i=33568
# Start: i=33584
# End: i=33584
# Start: i=33600
# End: i=33600
# Start: i=33616
# End: i=33616
# Start: i=33632
# End: i=33632
# Start: i=33648
# End: i=33648
# Start: i=33664
# End: i=33664
# Start: i=33680
# End: i=33680
# Start: i=33696
# End: i=33696
# Start: i=33712
# End: i=33712
# Start: i=33728
# End: i=33728
# Start: i=33744
# End: i=33744
# Start: i=33760
# End: i=33760
# Start: i=33776
# End: i=33776
# Start: i=33792
# End: i=33792
# Start: i=33808
# End: i=33808
# Start: i=33824
# End: i=33824
# Start: i=33840
# End: i=33840
# Start: i=33856
# End: i=33856
# Start: i=33872
# End: i=33872
# Start: i=33888
# End: i=33888
# Start: i=33904
# End: i=33904
# Start: i=33920
# End: i=33920
# Start: i=33936
# End: i=33936
# Start: i=33952
# End: i=33952
# Start: i=33968
# End: i=33968
# Start: i=33984
# End: i=33984
# Start: i=34000
# End: i=34000
# Start: i=34016
# End: i=34016
# Start: i=34032
# End: i=34032
# Start: i=34048
# End: i=34048
# Start: i=34064
# End: i=34064
# Start: i=34080
# End: i=34080
# Start: i=34096
# End: i=34096
# Start: i=34112
# End: i=34112
# Start: i=34128
# End: i=34128
# Start: i=34144
# End: i=34144
# Start: i=34160
# End: i=34160
# Start: i=34176
# End: i=34176
# Start: i=34192
# End: i=34192
# Start: i=34208
# End: i=34208
# Start: i=34224
# End: i=34224
# Start: i=34240
# End: i=34240
# Start: i=34256
# End: i=34256
# Start: i=34272
# End: i=34272
# Start: i=34288
# End: i=34288
# Start: i=34304
# End: i=34304
# Start: i=34320
# End: i=34320
# Start: i=34336
# End: i=34336
# Start: i=34352
# End: i=34352
# Start: i=34368
# End: i=34368
# Start: i=34384
# End: i=34384
# Start: i=34400
# End: i=34400
# Start: i=34416
# End: i=34416
# Start: i=34432
# End: i=34432
# Start: i=34448
# End: i=34448
# Start: i=34464
# End: i=34464
# Start: i=34480
# End: i=34480
# Start: i=34496
# End: i=34496
# Start: i=34512
# End: i=34512
# Start: i=34528
# End: i=34528
# Start: i=34544
# End: i=34544
# Start: i=34560
# End: i=34560
# Start: i=34576
# End: i=34576
# Start: i=34592
# End: i=34592
# Start: i=34608
# End: i=34608
# Start: i=34624
# End: i=34624
# Start: i=34640
# End: i=34640
# Start: i=34656
# End: i=34656
# Start: i=34672
# End: i=34672
# Start: i=34688
# End: i=34688
# Start: i=34704
# End: i=34704
# Start: i=34720
# End: i=34720
# Start: i=34736
# End: i=34736
# Start: i=34752
# End: i=34752
# Start: i=34768
# End: i=34768
# Start: i=34784
# End: i=34784
# Start: i=34800
# End: i=34800
# Start: i=34816
# End: i=34816
# Start: i=34832
# End: i=34832
# Start: i=34848
# End: i=34848
# Start: i=34864
# End: i=34864
# Start: i=34880
# End: i=34880
# Start: i=34896
# End: i=34896
# Start: i=34912
# End: i=34912
# Start: i=34928
# End: i=34928
# Start: i=34944
# End: i=34944
# Start: i=34960
# End: i=34960
# Start: i=34976
# End: i=34976
# Start: i=34992
# End: i=34992
# Start: i=35008
# End: i=35008
# Start: i=35024
# End: i=35024
# Start: i=35040
# End: i=35040
# Start: i=35056
# End: i=35056
# Start: i=35072
# End: i=35072
# Start: i=35088
# End: i=35088
# Start: i=35104
# End: i=35104
# Start: i=35120
# End: i=35120
# Start: i=35136
# End: i=35136
# Start: i=35152
# End: i=35152
# Start: i=35168
# End: i=35168
# Start: i=35184
# End: i=35184
# Start: i=35200
# End: i=35200
# Start: i=35216
# End: i=35216
# Start: i=35232
# End: i=35232
# Start: i=35248
# End: i=35248
# Start: i=35264
# End: i=35264
# Start: i=35280
# End: i=35280
# Start: i=35296
# End: i=35296
# Start: i=35312
# End: i=35312
# Start: i=35328
# End: i=35328
# Start: i=35344
# End: i=35344
# Start: i=35360
# End: i=35360
# Start: i=35376
# End: i=35376
# Start: i=35392
# End: i=35392
# Start: i=35408
# End: i=35408
# Start: i=35424
# End: i=35424
# Start: i=35440
# End: i=35440
# Start: i=35456
# End: i=35456
# Start: i=35472
# End: i=35472
# Start: i=35488
# End: i=35488
# Start: i=35504
# End: i=35504
# Start: i=35520
# End: i=35520
# Start: i=35536
# End: i=35536
# Start: i=35552
# End: i=35552
# Start: i=35568
# End: i=35568
# Start: i=35584
# End: i=35584
# Start: i=35600
# End: i=35600
# Start: i=35616
# End: i=35616
# Start: i=35632
# End: i=35632
# Start: i=35648
# End: i=35648
# Start: i=35664
# End: i=35664
# Start: i=35680
# End: i=35680
# Start: i=35696
# End: i=35696
# Start: i=35712
# End: i=35712
# Start: i=35728
# End: i=35728
# Start: i=35744
# End: i=35744
# Start: i=35760
# End: i=35760
# Start: i=35776
# End: i=35776
# Start: i=35792
# End: i=35792
# Start: i=35808
# End: i=35808
# Start: i=35824
# End: i=35824
# Start: i=35840
# End: i=35840
# Start: i=35856
# End: i=35856
# Start: i=35872
# End: i=35872
# Start: i=35888
# End: i=35888
# Start: i=35904
# End: i=35904
# Start: i=35920
# End: i=35920
# Start: i=35936
# End: i=35936
# Start: i=35952
# End: i=35952
# Start: i=35968
# End: i=35968
# Start: i=35984
# End: i=35984
# Start: i=36000
# End: i=36000
# Start: i=36016
# End: i=36016
# Start: i=36032
# End: i=36032
# Start: i=36048
# End: i=36048
# Start: i=36064
# End: i=36064
# Start: i=36080
# End: i=36080
# Start: i=36096
# End: i=36096
# Start: i=36112
# End: i=36112
# Start: i=36128
# End: i=36128
# Start: i=36144
# End: i=36144
# Start: i=36160
# End: i=36160
# Start: i=36176
# End: i=36176
# Start: i=36192
# End: i=36192
# Start: i=36208
# End: i=36208
# Start: i=36224
# End: i=36224
# Start: i=36240
# End: i=36240
# Start: i=36256
# End: i=36256
# Start: i=36272
# End: i=36272
# Start: i=36288
# End: i=36288
# Start: i=36304
# End: i=36304
# Start: i=36320
# End: i=36320
# Start: i=36336
# End: i=36336
# Start: i=36352
# End: i=36352
# Start: i=36368
# End: i=36368
# Start: i=36384
# End: i=36384
# Start: i=36400
# End: i=36400
# Start: i=36416
# End: i=36416
# Start: i=36432
# End: i=36432
# Start: i=36448
# End: i=36448
# Start: i=36464
# End: i=36464
# Start: i=36480
# End: i=36480
# Start: i=36496
# End: i=36496
# Start: i=36512
# End: i=36512
# Start: i=36528
# End: i=36528
# Start: i=36544
# End: i=36544
# Start: i=36560
# End: i=36560
# Start: i=36576
# End: i=36576
# Start: i=36592
# End: i=36592
# Start: i=36608
# End: i=36608
# Start: i=36624
# End: i=36624
# Start: i=36640
# End: i=36640
# Start: i=36656
# End: i=36656
# Start: i=36672
# End: i=36672
# Start: i=36688
# End: i=36688
# Start: i=36704
# End: i=36704
# Start: i=36720
# End: i=36720
# Start: i=36736
# End: i=36736
# Start: i=36752
# End: i=36752
# Start: i=36768
# End: i=36768
# Start: i=36784
# End: i=36784
# Start: i=36800
# End: i=36800
# Start: i=36816
# End: i=36816
# Start: i=36832
# End: i=36832
# Start: i=36848
# End: i=36848
# Start: i=36864
# End: i=36864
# Start: i=36880
# End: i=36880
# Start: i=36896
# End: i=36896
# Start: i=36912
# End: i=36912
# Start: i=36928
# End: i=36928
# Start: i=36944
# End: i=36944
# Start: i=36960
# End: i=36960
# Start: i=36976
# End: i=36976
# Start: i=36992
# End: i=36992
# Start: i=37008
# End: i=37008
# Start: i=37024
# End: i=37024
# Start: i=37040
# End: i=37040
# Start: i=37056
# End: i=37056
# Start: i=37072
# End: i=37072
# Start: i=37088
# End: i=37088
# Start: i=37104
# End: i=37104

# %%
print(tesla_tweets.head())
sentiment_counts = tesla_tweets['Sentiment'].value_counts()
print(sentiment_counts)
# Out:
#          Date                                              Tweet Sentiment
# 0  2022-09-29  mainstream media has done an amazing job at br...   LABEL_1
# 1  2022-09-29  tesla delivery estimates are at around 364k fr...   LABEL_1
# 2  2022-09-29  3/ even if i include 63.0m unvested rsus as of...   LABEL_2
# 3  2022-09-29     hahaha why are you still trying to stop tes...   LABEL_1
# 4  2022-09-29    stop trying to kill kids, you sad deranged o...   LABEL_0
# Sentiment
# LABEL_1    19399
# LABEL_2    14036
# LABEL_0     3671
# Name: count, dtype: int64

# %%
# %cd "/content"
# Out:
# /content

# %%
tesla_stock_data = pd.read_csv('tesla_historical_stock_prices.csv')
print(tesla_stock_data.head())
# Out:
#         Date    Open    High     Low  Close   Adj Close       Volume
# 0  29-Sep-22  282.76  283.65  265.78  268.21      268.21  77,620,600
# 1  28-Sep-22  283.08  289.00  277.57  287.81      287.81  54,664,800
# 2  27-Sep-22  283.84  288.67  277.51  282.94      282.94  61,925,200
# 3  26-Sep-22  271.83  284.09  270.31  276.01      276.01  58,076,900
# 4  23-Sep-22  283.09  284.50  272.82  275.33      275.33  63,748,400

# %%
tesla_stock_data['Date'] = pd.to_datetime(tesla_stock_data['Date'], format='%d-%b-%y')
tesla_stock_data.columns = tesla_stock_data.columns.str.strip()
tesla_stock_data = tesla_stock_data[['Date', 'Adj Close', 'Volume']].copy()
tesla_stock_data.rename(columns={'Adj Close': 'Price'}, inplace=True)
print(tesla_stock_data.head())
# Out:
#         Date   Price      Volume
# 0 2022-09-29  268.21  77,620,600
# 1 2022-09-28  287.81  54,664,800
# 2 2022-09-27  282.94  61,925,200
# 3 2022-09-26  276.01  58,076,900
# 4 2022-09-23  275.33  63,748,400

# %%
tesla_sentiment_data = tesla_tweets[['Date', 'Sentiment']]

# convert sentiment labels to numeric values
sentiment_mapping = {"LABEL_2": 1, "LABEL_1": 0, "LABEL_0": -1}
tesla_sentiment_data['sentiment_numeric'] = tesla_sentiment_data['Sentiment'].map(sentiment_mapping)
# make sure dates are in the right format
tesla_stock_data['Date'] = pd.to_datetime(tesla_stock_data['Date'])
tesla_sentiment_data['Date'] = pd.to_datetime(tesla_sentiment_data['Date'])
# aggregate sentiment scores by date (taking the average sentiment for each day)
daily_sentiment = tesla_sentiment_data.groupby('Date')['sentiment_numeric'].mean().reset_index()

daily_sentiment.rename(columns={'sentiment_numeric': 'daily_sentiment'}, inplace=True)
# interpolate missing prices
tesla_stock_data['Volume'] = tesla_stock_data['Volume'].str.replace(',', '').astype(float)
tesla_stock_data['Price'] = pd.to_numeric(tesla_stock_data['Price'], errors='coerce')

tesla_stock_data = tesla_stock_data.set_index('Date').asfreq('D')
tesla_stock_data['Volume'] = tesla_stock_data['Volume'].interpolate(method='linear', limit_direction='both')
tesla_stock_data['Price'] = tesla_stock_data['Price'].interpolate(method='linear', limit_direction='both')
tesla_stock_data = tesla_stock_data.reset_index()

# %%
#tesla_stock_data = tesla_stock_data.interpolate().reset_index()
# merge Tesla stock data with sentiment data on date
merged_data = pd.merge(tesla_stock_data, daily_sentiment, on='Date', how='inner')

# Fill missing values in Volume column after merging (if any)
merged_data['Volume'] = merged_data['Volume'].fillna(merged_data['Volume'].median())

# Output the merged data
print(merged_data.head())
# Out:
#         Date   Price      Volume  daily_sentiment
# 0 2021-09-30  258.49  53868000.0         0.266667
# 1 2021-10-01  258.41  51094200.0         0.382979
# 2 2021-10-02  259.11  64546100.0         0.321739
# 3 2021-10-03  259.81  77998000.0         0.327869
# 4 2021-10-04  260.51  91449900.0         0.186441

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np

# %%
def prepare_sequences(data, lookback):
  """
  Prepare sequences for LSTM model.

  Args:
  data (pd.DataFrame): DataFrame with date, price, volume, and daily_sentiment
  lookback (int): No. of previous days to use for prediction

  Returns:
  X (np.array): Input features for LSTM
  y (np.array): Target stock prices
  """

  data = data.sort_values('Date')

  sentiment_data = data['daily_sentiment'].values
  price_data = data['Price'].values

  sentiment_scaler = MinMaxScaler(feature_range=(-1, 1))
  price_scaler = MinMaxScaler(feature_range=(0, 1))

  sentiment_scaled = sentiment_scaler.fit_transform(sentiment_data.reshape(-1, 1))
  price_scaled = price_scaler.fit_transform(price_data.reshape(-1, 1))

  X, y = [], []

  for i in range(len(data) - lookback):
    input_seq = np.column_stack([sentiment_scaled[i:i+lookback].flatten(), price_scaled[i:i+lookback].flatten()])
    X.append(input_seq)
    y.append(price_scaled[i+lookback])

  return np.array(X), np.array(y)

# %%
def create_lstm_model(input_shape):
  """
  Create LSTM model for stock price prediction.

  Args:
  input_shape (tuple): Shape of input data

  Returns:
  model (tf.keras.Model): LSTM model
  """

  model = Sequential([
      LSTM(units=50, activation='relu', return_sequences=True, input_shape=input_shape),
      Dropout(0.2),
      LSTM(units=50, activation='relu'),
      Dropout(0.2),
      Dense(units=25, activation='relu'),
      Dense(units=1)
  ])

  model.compile(optimizer='adam', loss='mse', metrics=['mae'])
  return model

# %%
def train_and_evaluate_model(data, lookback, test_size=0.2, epochs=50, batch_size=32):
  """
  Train and evaluate LSTM model for stock price prediction.

  Args:
  data (pd.DataFrame): DataFrame with date, price, volume, and daily_sentiment
  lookback (int): No. of previous days to use for prediction
  test_size (float): Proportion of data to use for testing
  epochs (int): No. of epochs to train the model
  batch_size (int): Batch size for training

  Returns:
  model (tf.keras.Model): Trained LSTM model
  history (tf.keras.callbacks.History): Training history
  """

  X, y = prepare_sequences(data, lookback)
  X = X.reshape(X.shape[0], X.shape[1], 2) # 2 features: sentiment and price

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, shuffle=False)

  model = create_lstm_model(input_shape=(lookback, 2))
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test), verbose=1)

  loss, mae = model.evaluate(X_test, y_test)
  print(f'Test Loss: {loss:.4f}, Test MAE: {mae:.4f}')

  return model, history

# %%
def predict_stock_prices(model, data, lookback, future_days):
  """
  Predict stock prices for future days.

  Args:
  model (tf.keras.Model): Trained LSTM model
  data (pd.DataFrame): DataFrame with date, price, volume, and daily sentiment
  lookback (int): No. of previous days to use for prediction
  future_days (int): No. of future days to predict

  Returns:
  predictions (np.array): Predicted stock prices
  """

  sentiment_data = data['daily_sentiment'].values
  price_data = data['Price'].values

  sentiment_scaler = MinMaxScaler(feature_range=(-1, 1))
  price_scaler = MinMaxScaler(feature_range=(0, 1))

  sentiment_scaled = sentiment_scaler.fit_transform(sentiment_data.reshape(-1, 1))
  price_scaled = price_scaler.fit_transform(price_data.reshape(-1, 1))

  recent_seq = np.column_stack([sentiment_scaled[-lookback:].flatten(), price_scaled[-lookback:].flatten()])
  recent_seq = recent_seq.reshape(1, lookback, 2)  # 2 features: sentiment and price

  predictions = []
  curr_seq = recent_seq

  for _ in range(future_days):
    next_price_scaled = model.predict(curr_seq)
    next_price = price_scaler.inverse_transform(next_price_scaled)[0][0]
    predictions.append(next_price)

    curr_seq = np.roll(curr_seq, -1, axis=1)
    curr_seq[0, -1, 1] = next_price_scaled

  return np.array(predictions)

# %%
print(merged_data.head())

lstm_model, history = train_and_evaluate_model(merged_data, lookback=7)
future_prices = predict_stock_prices(lstm_model, merged_data, lookback=7, future_days=7)
# Out:
#         Date   Price      Volume  daily_sentiment
# 0 2021-09-30  258.49  53868000.0         0.266667
# 1 2021-10-01  258.41  51094200.0         0.382979
# 2 2021-10-02  259.11  64546100.0         0.321739
# 3 2021-10-03  259.81  77998000.0         0.327869
# 4 2021-10-04  260.51  91449900.0         0.186441
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - loss: 0.2367 - mae: 0.4230 - val_loss: 0.0676 - val_mae: 0.2513
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1043 - mae: 0.2656 - val_loss: 0.0039 - val_mae: 0.0512
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0426 - mae: 0.1679 - val_loss: 0.0226 - val_mae: 0.1400
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0343 - mae: 0.1513 - val_loss: 0.0028 - val_mae: 0.0457
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234 - mae: 0.1262 - val_loss: 0.0029 - val_mae: 0.0449
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0176 - mae: 0.1094 - val_loss: 0.0040 - val_mae: 0.0500
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0127 - mae: 0.0919 - val_loss: 0.0067 - val_mae: 0.0667
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121 - mae: 0.0877 - val_loss: 0.0052 - val_mae: 0.0579
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0117 - mae: 0.0863 - val_loss: 0.0047 - val_mae: 0.0558
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0134 - mae: 0.0902 - val_loss: 0.0046 - val_mae: 0.0555
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109 - mae: 0.0818 - val_loss: 0.0047 - val_mae: 0.0558
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116 - mae: 0.0860 - val_loss: 0.0043 - val_mae: 0.0542
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - mae: 0.0725 - val_loss: 0.0055 - val_mae: 0.0597
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108 - mae: 0.0818 - val_loss: 0.0045 - val_mae: 0.0549
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - mae: 0.0823 - val_loss: 0.0044 - val_mae: 0.0540
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - mae: 0.0815 - val_loss: 0.0042 - val_mae: 0.0535
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101 - mae: 0.0780 - val_loss: 0.0055 - val_mae: 0.0591
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111 - mae: 0.0820 - val_loss: 0.0042 - val_mae: 0.0531
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098 - mae: 0.0741 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0090 - mae: 0.0747 - val_loss: 0.0040 - val_mae: 0.0522
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0100 - mae: 0.0788 - val_loss: 0.0048 - val_mae: 0.0555
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085 - mae: 0.0715 - val_loss: 0.0039 - val_mae: 0.0518
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0092 - mae: 0.0754 - val_loss: 0.0045 - val_mae: 0.0542
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0101 - mae: 0.0796 - val_loss: 0.0043 - val_mae: 0.0528
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0098 - mae: 0.0786 - val_loss: 0.0042 - val_mae: 0.0518
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0087 - mae: 0.0722 - val_loss: 0.0044 - val_mae: 0.0539
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - mae: 0.0797 - val_loss: 0.0043 - val_mae: 0.0518
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0082 - mae: 0.0712 - val_loss: 0.0037 - val_mae: 0.0500
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0094 - mae: 0.0756 - val_loss: 0.0039 - val_mae: 0.0511
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0089 - mae: 0.0751 - val_loss: 0.0040 - val_mae: 0.0514
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0080 - mae: 0.0688 - val_loss: 0.0036 - val_mae: 0.0491
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0073 - mae: 0.0660 - val_loss: 0.0037 - val_mae: 0.0487
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0071 - mae: 0.0674 - val_loss: 0.0041 - val_mae: 0.0501
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0077 - mae: 0.0716 - val_loss: 0.0038 - val_mae: 0.0495
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062 - mae: 0.0597 - val_loss: 0.0036 - val_mae: 0.0480
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0086 - mae: 0.0716 - val_loss: 0.0038 - val_mae: 0.0477
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064 - mae: 0.0648 - val_loss: 0.0038 - val_mae: 0.0492
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0074 - mae: 0.0682 - val_loss: 0.0042 - val_mae: 0.0500
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - mae: 0.0674 - val_loss: 0.0035 - val_mae: 0.0457
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - mae: 0.0674 - val_loss: 0.0036 - val_mae: 0.0469
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mae: 0.0672 - val_loss: 0.0042 - val_mae: 0.0520
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mae: 0.0643 - val_loss: 0.0047 - val_mae: 0.0526
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mae: 0.0668 - val_loss: 0.0036 - val_mae: 0.0480
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - mae: 0.0665 - val_loss: 0.0039 - val_mae: 0.0486
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0611 - val_loss: 0.0040 - val_mae: 0.0504
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - mae: 0.0715 - val_loss: 0.0040 - val_mae: 0.0503
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mae: 0.0642 - val_loss: 0.0042 - val_mae: 0.0524
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068 - mae: 0.0664 - val_loss: 0.0040 - val_mae: 0.0502
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mae: 0.0667 - val_loss: 0.0045 - val_mae: 0.0551
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - mae: 0.0638 - val_loss: 0.0040 - val_mae: 0.0505
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0520
# Test Loss: 0.0040, Test MAE: 0.0505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled
# <ipython-input-34-587a778bbec1>:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   curr_seq[0, -1, 1] = next_price_scaled

# %%
import matplotlib.pyplot as plt

print(future_prices)

def plot_training_history(history):
  """
  Plot training history for loss and MAE.

  Args:
  history (tf.keras.callbacks.History): Training history
  """

  plt.figure(figsize=(10, 6))
  plt.subplot(1, 2, 1)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.plot(history.history['mae'], label='Training MAE')
  plt.plot(history.history['val_mae'], label='Validation MAE')
  plt.title('Mean Absolute Error')
  plt.xlabel('Epoch')
  plt.ylabel('MAE')
  plt.legend()

  plt.tight_layout()
  plt.show()

plot_training_history(history)
# Out:
# [282.12296 281.19055 283.42206 283.1612  284.56686 288.59915 290.38126]

# %%
def plot_predictions(data, future_prices, future_days=5):
  last_date = pd.to_datetime(data['Date'].max())
  future_dates = pd.date_range(start=last_date, periods=future_days+1)[1:]

  plt.figure(figsize=(15, 7))
  plt.plot(data['Date'], data['Price'].values, label='Historical Prices', color='blue')
  plt.plot(future_dates, future_prices, label='Predicted Prices', color='red')

  plt.axvline(x=last_date, color='black', linestyle=':', label='Prediction Start')

  plt.title('Stock Price Prediction')
  plt.xlabel('Date')
  plt.ylabel('Stock Price')
  plt.legend()
  plt.show()

plot_predictions(merged_data, future_prices, future_days=7)

# %%
def predict_stock_prices_full_range(model, data, lookback):
  """
  Predict stock prices for future days.

  Args:
  model (tf.keras.Model): Trained LSTM model
  data (pd.DataFrame): DataFrame with date, price, volume, and daily sentiment
  lookback (int): No. of previous days to use for prediction
  future_days (int): No. of future days to predict

  Returns:
  predictions (np.array): Predicted stock prices
  """

  sentiment_data = data['daily_sentiment'].values
  price_data = data['Price'].values
  dates = data['Date']

  sentiment_scaler = MinMaxScaler(feature_range=(-1, 1))
  price_scaler = MinMaxScaler(feature_range=(0, 1))

  sentiment_scaled = sentiment_scaler.fit_transform(sentiment_data.reshape(-1, 1))
  price_scaled = price_scaler.fit_transform(price_data.reshape(-1, 1))

  X, y_actual = [], []

  for i in range(len(data) - lookback):
    input_seq = np.column_stack([sentiment_scaled[i:i+lookback].flatten(), price_scaled[i:i+lookback].flatten()])
    X.append(input_seq)
    y_actual.append(price_scaled[i+lookback])

  X = np.array(X).reshape(len(X), lookback, 2)
  y_actual = np.array(y_actual)

  y_pred_scaled = model.predict(X)
  y_pred = price_scaler.inverse_transform(y_pred_scaled)
  y_actual = price_scaler.inverse_transform(y_actual)

  mse = np.mean((y_pred - y_actual)**2)
  mae = np.mean(np.abs(y_pred - y_actual))

  return {
      'dates': dates[lookback:],
      'actual_prices': y_actual.flatten(),
      'predicted_prices': y_pred.flatten(),
      'mse': mse,
      'mae': mae
  }

# %%
def plot_price_predictions(pred_results):
  plt.figure(figsize=(15, 7))

  plt.plot(pred_results['dates'], pred_results['actual_prices'], label='Actual Prices', color='blue')
  plt.plot(pred_results['dates'], pred_results['predicted_prices'], label='Predicted Prices', color='red')

  plt.title('Tesla Stock Prices: Actual vs. Predicted')
  plt.xlabel('Date')
  plt.ylabel('Stock Price')
  plt.legend()

  plt.text(0.05, 0.95,
           f'Mean Squared Error: ${pred_results["mse"]: .2f}\n'
           f'Mean Absolute Error: ${pred_results["mae"]: .2f}',
           transform=plt.gca().transAxes,
           verticalalignment='top',
           bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

  plt.show()

# %%
pred_results = predict_stock_prices_full_range(lstm_model, merged_data, lookback=7)
plot_price_predictions(pred_results)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
